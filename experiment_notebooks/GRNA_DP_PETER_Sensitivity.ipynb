# %%
# !git clone https://github.com/haider4445/FLinferenceDefence.git
# Out:
# Cloning into 'FLinferenceDefence'...
# remote: Enumerating objects: 506, done.
# remote: Counting objects: 100% (442/442), done.
# remote: Compressing objects: 100% (204/204), done.
# remote: Total 506 (delta 316), reused 357 (delta 237), pack-reused 64
# Receiving objects: 100% (506/506), 64.31 MiB | 18.08 MiB/s, done.
# Resolving deltas: 100% (335/335), done.
# Updating files: 100% (313/313), done.

# %%
# !pip install diffprivlib
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 176.0/176.0 kB 1.3 MB/s eta 0:00:00
# ...

# %%
# !pip install tenseal
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 12.3 MB/s eta 0:00:00
# ...

# %%
# %cd FLinferenceDefence/GRNA
# Out:
# /content/FLinferenceDefence/GRNA

# %% [markdown]
# # GRNA DP Epsilon = 10

# %%
# !python main-grna.py --outputDim 5 --modelType NN --DataFile news_cleaned.csv --LogFile news.csv --n_attacker 15 --n_victim 44 --runtimes 2 --EnablePREDVEL False --perturbation_level -4 --EnableDP True --DPEpsilon 0.5 --DPDelta 1e-5 --DPSensitivity 0.01
# Out:
# {'DataFile': 'news_cleaned.csv', 'LogFile': 'news.csv', 'n_attacker': 15, 'n_victim': 44, 'runtimes': 2, 'trainpart': 0.6, 'testpart': 0.2, 'predictpart': 0.2, 'enableConfRound': False, 'EnablePREDVEL': True, 'EnableNoising': False, 'EnableDropout': False, 'EnableDP': True, 'EnableEncryption': False, 'DPEpsilon': 0.5, 'DPDelta': 1e-05, 'DPSensitivity': 0.01, 'roundPrecision': 1, 'StdDevNoising': 0.1, 'epochsForAttack': 60, 'epochsForClassifier': 60, 'meanLambda': 1.2, 'enableAttackerFeatures': True, 'enableMean': False, 'unknownVarLambda': 0.25, 'perturbation_level': -4.0, 'outputDim': 5, 'modelType': 'NN'}
#
#
#
# <<<<<<<-------------------------------NumOfFeaturesToRecover: 44------------------------------->>>>>>>
# Running on device: cuda:0
# Writing log to file: /content/FLinferenceDefence/GRNA/log/news-2023-08-17-16-40-55-attacker-15-victim-44-mean-False-type-NN-predict-0.2.csv
# n_attacker = 15, n_victim = 44
#
#
# <----------------- Running count: 1 / 2 ----------------->
#
#
# ...

# %%
# !python main-grna.py --outputDim 5 --modelType NN --DataFile news_cleaned.csv --LogFile news.csv --n_attacker 30 --n_victim 29 --runtimes 2 --EnablePREDVEL False --perturbation_level -4 --EnableDP True --DPEpsilon 0.5 --DPDelta 1e-5 --DPSensitivity 0.01
# Out:
# {'DataFile': 'news_cleaned.csv', 'LogFile': 'news.csv', 'n_attacker': 30, 'n_victim': 29, 'runtimes': 2, 'trainpart': 0.6, 'testpart': 0.2, 'predictpart': 0.2, 'enableConfRound': False, 'EnablePREDVEL': True, 'EnableNoising': False, 'EnableDropout': False, 'EnableDP': True, 'EnableEncryption': False, 'DPEpsilon': 0.5, 'DPDelta': 1e-05, 'DPSensitivity': 0.01, 'roundPrecision': 1, 'StdDevNoising': 0.1, 'epochsForAttack': 60, 'epochsForClassifier': 60, 'meanLambda': 1.2, 'enableAttackerFeatures': True, 'enableMean': False, 'unknownVarLambda': 0.25, 'perturbation_level': -4.0, 'outputDim': 5, 'modelType': 'NN'}
#
#
#
# <<<<<<<-------------------------------NumOfFeaturesToRecover: 29------------------------------->>>>>>>
# Running on device: cuda:0
# Writing log to file: /content/FLinferenceDefence/GRNA/log/news-2023-08-17-16-46-33-attacker-30-victim-29-mean-False-type-NN-predict-0.2.csv
# n_attacker = 30, n_victim = 29
#
#
# <----------------- Running count: 1 / 2 ----------------->
#
#
# ...

# %%
# !python main-grna.py --outputDim 5 --modelType NN --DataFile news_cleaned.csv --LogFile news.csv --n_attacker 45 --n_victim 14 --runtimes 2 --EnablePREDVEL False --perturbation_level -4 --EnableDP True --DPEpsilon 0.5 --DPDelta 1e-5 --DPSensitivity 0.01
# Out:
# {'DataFile': 'news_cleaned.csv', 'LogFile': 'news.csv', 'n_attacker': 45, 'n_victim': 14, 'runtimes': 2, 'trainpart': 0.6, 'testpart': 0.2, 'predictpart': 0.2, 'enableConfRound': False, 'EnablePREDVEL': True, 'EnableNoising': False, 'EnableDropout': False, 'EnableDP': True, 'EnableEncryption': False, 'DPEpsilon': 0.5, 'DPDelta': 1e-05, 'DPSensitivity': 0.01, 'roundPrecision': 1, 'StdDevNoising': 0.1, 'epochsForAttack': 60, 'epochsForClassifier': 60, 'meanLambda': 1.2, 'enableAttackerFeatures': True, 'enableMean': False, 'unknownVarLambda': 0.25, 'perturbation_level': -4.0, 'outputDim': 5, 'modelType': 'NN'}
#
#
#
# <<<<<<<-------------------------------NumOfFeaturesToRecover: 14------------------------------->>>>>>>
# Running on device: cuda:0
# Writing log to file: /content/FLinferenceDefence/GRNA/log/news-2023-08-17-16-51-27-attacker-45-victim-14-mean-False-type-NN-predict-0.2.csv
# n_attacker = 45, n_victim = 14
#
#
# <----------------- Running count: 1 / 2 ----------------->
#
#
# ...

# %%
# !python main-grna.py --outputDim 5 --modelType RF --DataFile news_cleaned.csv --LogFile news.csv --n_attacker 15 --n_victim 44 --runtimes 2 --EnablePREDVEL False --perturbation_level -4 --EnableDP True --DPEpsilon 0.5 --DPDelta 1e-5 --DPSensitivity 0.01
# Out:
# {'DataFile': 'news_cleaned.csv', 'LogFile': 'news.csv', 'n_attacker': 15, 'n_victim': 44, 'runtimes': 2, 'trainpart': 0.6, 'testpart': 0.2, 'predictpart': 0.2, 'enableConfRound': False, 'EnablePREDVEL': True, 'EnableNoising': False, 'EnableDropout': False, 'EnableDP': True, 'EnableEncryption': False, 'DPEpsilon': 0.5, 'DPDelta': 1e-05, 'DPSensitivity': 0.01, 'roundPrecision': 1, 'StdDevNoising': 0.1, 'epochsForAttack': 60, 'epochsForClassifier': 60, 'meanLambda': 1.2, 'enableAttackerFeatures': True, 'enableMean': False, 'unknownVarLambda': 0.25, 'perturbation_level': -4.0, 'outputDim': 5, 'modelType': 'RF'}
#
#
#
# <<<<<<<-------------------------------NumOfFeaturesToRecover: 44------------------------------->>>>>>>
# Running on device: cuda:0
# Writing log to file: /content/FLinferenceDefence/GRNA/log/news-2023-08-17-16-55-52-attacker-15-victim-44-mean-False-type-RF-predict-0.2.csv
# n_attacker = 15, n_victim = 44
#
#
# <----------------- Running count: 1 / 2 ----------------->
#
#
# ...

# %%
# !python main-grna.py --outputDim 5 --modelType RF --DataFile news_cleaned.csv --LogFile news.csv --n_attacker 30 --n_victim 29 --runtimes 2 --EnablePREDVEL False --perturbation_level -4 --EnableDP True --DPEpsilon 0.5 --DPDelta 1e-5 --DPSensitivity 0.01
# Out:
# {'DataFile': 'news_cleaned.csv', 'LogFile': 'news.csv', 'n_attacker': 30, 'n_victim': 29, 'runtimes': 2, 'trainpart': 0.6, 'testpart': 0.2, 'predictpart': 0.2, 'enableConfRound': False, 'EnablePREDVEL': True, 'EnableNoising': False, 'EnableDropout': False, 'EnableDP': True, 'EnableEncryption': False, 'DPEpsilon': 0.5, 'DPDelta': 1e-05, 'DPSensitivity': 0.01, 'roundPrecision': 1, 'StdDevNoising': 0.1, 'epochsForAttack': 60, 'epochsForClassifier': 60, 'meanLambda': 1.2, 'enableAttackerFeatures': True, 'enableMean': False, 'unknownVarLambda': 0.25, 'perturbation_level': -4.0, 'outputDim': 5, 'modelType': 'RF'}
#
#
#
# <<<<<<<-------------------------------NumOfFeaturesToRecover: 29------------------------------->>>>>>>
# Running on device: cuda:0
# Writing log to file: /content/FLinferenceDefence/GRNA/log/news-2023-08-17-17-01-37-attacker-30-victim-29-mean-False-type-RF-predict-0.2.csv
# n_attacker = 30, n_victim = 29
#
#
# <----------------- Running count: 1 / 2 ----------------->
#
#
# ...

# %%
# !python main-grna.py --outputDim 5 --modelType RF --DataFile news_cleaned.csv --LogFile news.csv --n_attacker 45 --n_victim 14 --runtimes 2 --EnablePREDVEL False --perturbation_level -4 --EnableDP True --DPEpsilon 0.5 --DPDelta 1e-5 --DPSensitivity 0.01
# Out:
# {'DataFile': 'news_cleaned.csv', 'LogFile': 'news.csv', 'n_attacker': 45, 'n_victim': 14, 'runtimes': 2, 'trainpart': 0.6, 'testpart': 0.2, 'predictpart': 0.2, 'enableConfRound': False, 'EnablePREDVEL': True, 'EnableNoising': False, 'EnableDropout': False, 'EnableDP': True, 'EnableEncryption': False, 'DPEpsilon': 0.5, 'DPDelta': 1e-05, 'DPSensitivity': 0.01, 'roundPrecision': 1, 'StdDevNoising': 0.1, 'epochsForAttack': 60, 'epochsForClassifier': 60, 'meanLambda': 1.2, 'enableAttackerFeatures': True, 'enableMean': False, 'unknownVarLambda': 0.25, 'perturbation_level': -4.0, 'outputDim': 5, 'modelType': 'RF'}
#
#
#
# <<<<<<<-------------------------------NumOfFeaturesToRecover: 14------------------------------->>>>>>>
# Running on device: cuda:0
# Writing log to file: /content/FLinferenceDefence/GRNA/log/news-2023-08-17-17-06-54-attacker-45-victim-14-mean-False-type-RF-predict-0.2.csv
# n_attacker = 45, n_victim = 14
#
#
# <----------------- Running count: 1 / 2 ----------------->
#
#
# ...

# %%
# !python main-grna.py --outputDim 11 --modelType RF --DataFile drive_cleaned.csv --LogFile drive.csv --n_attacker 12 --n_victim 36 --runtimes 2 --EnablePREDVEL False --perturbation_level -4 --EnableDP True --DPEpsilon 0.5 --DPDelta 1e-5 --DPSensitivity 0.01
# Out:
# {'DataFile': 'drive_cleaned.csv', 'LogFile': 'drive.csv', 'n_attacker': 12, 'n_victim': 36, 'runtimes': 2, 'trainpart': 0.6, 'testpart': 0.2, 'predictpart': 0.2, 'enableConfRound': False, 'EnablePREDVEL': True, 'EnableNoising': False, 'EnableDropout': False, 'EnableDP': True, 'EnableEncryption': False, 'DPEpsilon': 0.5, 'DPDelta': 1e-05, 'DPSensitivity': 0.01, 'roundPrecision': 1, 'StdDevNoising': 0.1, 'epochsForAttack': 60, 'epochsForClassifier': 60, 'meanLambda': 1.2, 'enableAttackerFeatures': True, 'enableMean': False, 'unknownVarLambda': 0.25, 'perturbation_level': -4.0, 'outputDim': 11, 'modelType': 'RF'}
#
#
#
# <<<<<<<-------------------------------NumOfFeaturesToRecover: 36------------------------------->>>>>>>
# Running on device: cuda:0
# Writing log to file: /content/FLinferenceDefence/GRNA/log/drive-2023-08-17-17-11-41-attacker-12-victim-36-mean-False-type-RF-predict-0.2.csv
# n_attacker = 12, n_victim = 36
#
#
# <----------------- Running count: 1 / 2 ----------------->
# ...

# %%
# !python main-grna.py --outputDim 11 --modelType RF --DataFile drive_cleaned.csv --LogFile drive.csv --n_attacker 24 --n_victim 24 --runtimes 2 --EnablePREDVEL False --perturbation_level -4 --EnableDP True --DPEpsilon 0.5 --DPDelta 1e-5 --DPSensitivity 0.01
# Out:
# {'DataFile': 'drive_cleaned.csv', 'LogFile': 'drive.csv', 'n_attacker': 24, 'n_victim': 24, 'runtimes': 2, 'trainpart': 0.6, 'testpart': 0.2, 'predictpart': 0.2, 'enableConfRound': False, 'EnablePREDVEL': True, 'EnableNoising': False, 'EnableDropout': False, 'EnableDP': True, 'EnableEncryption': False, 'DPEpsilon': 0.5, 'DPDelta': 1e-05, 'DPSensitivity': 0.01, 'roundPrecision': 1, 'StdDevNoising': 0.1, 'epochsForAttack': 60, 'epochsForClassifier': 60, 'meanLambda': 1.2, 'enableAttackerFeatures': True, 'enableMean': False, 'unknownVarLambda': 0.25, 'perturbation_level': -4.0, 'outputDim': 11, 'modelType': 'RF'}
#
#
#
# <<<<<<<-------------------------------NumOfFeaturesToRecover: 24------------------------------->>>>>>>
# Running on device: cuda:0
# Writing log to file: /content/FLinferenceDefence/GRNA/log/drive-2023-08-17-17-21-47-attacker-24-victim-24-mean-False-type-RF-predict-0.2.csv
# n_attacker = 24, n_victim = 24
#
#
# <----------------- Running count: 1 / 2 ----------------->
# ...

# %%
# !python main-grna.py --outputDim 11 --modelType RF --DataFile drive_cleaned.csv --LogFile drive.csv --n_attacker 36 --n_victim 12 --runtimes 2 --EnablePREDVEL False --perturbation_level -4 --EnableDP True --DPEpsilon 0.5 --DPDelta 1e-5 --DPSensitivity 0.01
# Out:
# {'DataFile': 'drive_cleaned.csv', 'LogFile': 'drive.csv', 'n_attacker': 36, 'n_victim': 12, 'runtimes': 2, 'trainpart': 0.6, 'testpart': 0.2, 'predictpart': 0.2, 'enableConfRound': False, 'EnablePREDVEL': True, 'EnableNoising': False, 'EnableDropout': False, 'EnableDP': True, 'EnableEncryption': False, 'DPEpsilon': 0.5, 'DPDelta': 1e-05, 'DPSensitivity': 0.01, 'roundPrecision': 1, 'StdDevNoising': 0.1, 'epochsForAttack': 60, 'epochsForClassifier': 60, 'meanLambda': 1.2, 'enableAttackerFeatures': True, 'enableMean': False, 'unknownVarLambda': 0.25, 'perturbation_level': -4.0, 'outputDim': 11, 'modelType': 'RF'}
#
#
#
# <<<<<<<-------------------------------NumOfFeaturesToRecover: 12------------------------------->>>>>>>
# Running on device: cuda:0
# Writing log to file: /content/FLinferenceDefence/GRNA/log/drive-2023-08-17-17-31-33-attacker-36-victim-12-mean-False-type-RF-predict-0.2.csv
# n_attacker = 36, n_victim = 12
#
#
# <----------------- Running count: 1 / 2 ----------------->
# ...

# %%
# !python main-grna.py --outputDim 11 --modelType NN --DataFile drive_cleaned.csv --LogFile drive.csv --n_attacker 12 --n_victim 36 --runtimes 2 --EnablePREDVEL False --perturbation_level -4 --EnableDP True --DPEpsilon 0.5 --DPDelta 1e-5 --DPSensitivity 0.01
# Out:
# {'DataFile': 'drive_cleaned.csv', 'LogFile': 'drive.csv', 'n_attacker': 12, 'n_victim': 36, 'runtimes': 2, 'trainpart': 0.6, 'testpart': 0.2, 'predictpart': 0.2, 'enableConfRound': False, 'EnablePREDVEL': True, 'EnableNoising': False, 'EnableDropout': False, 'EnableDP': True, 'EnableEncryption': False, 'DPEpsilon': 0.5, 'DPDelta': 1e-05, 'DPSensitivity': 0.01, 'roundPrecision': 1, 'StdDevNoising': 0.1, 'epochsForAttack': 60, 'epochsForClassifier': 60, 'meanLambda': 1.2, 'enableAttackerFeatures': True, 'enableMean': False, 'unknownVarLambda': 0.25, 'perturbation_level': -4.0, 'outputDim': 11, 'modelType': 'NN'}
#
#
#
# <<<<<<<-------------------------------NumOfFeaturesToRecover: 36------------------------------->>>>>>>
# Running on device: cuda:0
# Writing log to file: /content/FLinferenceDefence/GRNA/log/drive-2023-08-17-17-40-41-attacker-12-victim-36-mean-False-type-NN-predict-0.2.csv
# n_attacker = 12, n_victim = 36
#
#
# <----------------- Running count: 1 / 2 ----------------->
# ...

# %%
# !python main-grna.py --outputDim 11 --modelType NN --DataFile drive_cleaned.csv --LogFile drive.csv --n_attacker 24 --n_victim 24 --runtimes 2 --EnablePREDVEL False --perturbation_level -4 --EnableDP True --DPEpsilon 0.5 --DPDelta 1e-5 --DPSensitivity 0.01
# Out:
# {'DataFile': 'drive_cleaned.csv', 'LogFile': 'drive.csv', 'n_attacker': 24, 'n_victim': 24, 'runtimes': 2, 'trainpart': 0.6, 'testpart': 0.2, 'predictpart': 0.2, 'enableConfRound': False, 'EnablePREDVEL': True, 'EnableNoising': False, 'EnableDropout': False, 'EnableDP': True, 'EnableEncryption': False, 'DPEpsilon': 0.5, 'DPDelta': 1e-05, 'DPSensitivity': 0.01, 'roundPrecision': 1, 'StdDevNoising': 0.1, 'epochsForAttack': 60, 'epochsForClassifier': 60, 'meanLambda': 1.2, 'enableAttackerFeatures': True, 'enableMean': False, 'unknownVarLambda': 0.25, 'perturbation_level': -4.0, 'outputDim': 11, 'modelType': 'NN'}
#
#
#
# <<<<<<<-------------------------------NumOfFeaturesToRecover: 24------------------------------->>>>>>>
# Running on device: cuda:0
# Writing log to file: /content/FLinferenceDefence/GRNA/log/drive-2023-08-17-17-50-16-attacker-24-victim-24-mean-False-type-NN-predict-0.2.csv
# n_attacker = 24, n_victim = 24
#
#
# <----------------- Running count: 1 / 2 ----------------->
# ...

# %%
# !python main-grna.py --outputDim 11 --modelType NN --DataFile drive_cleaned.csv --LogFile drive.csv --n_attacker 36 --n_victim 12 --runtimes 2 --EnablePREDVEL False --perturbation_level -4 --EnableDP True --DPEpsilon 0.5 --DPDelta 1e-5 --DPSensitivity 0.01
# Out:
# {'DataFile': 'drive_cleaned.csv', 'LogFile': 'drive.csv', 'n_attacker': 36, 'n_victim': 12, 'runtimes': 2, 'trainpart': 0.6, 'testpart': 0.2, 'predictpart': 0.2, 'enableConfRound': False, 'EnablePREDVEL': True, 'EnableNoising': False, 'EnableDropout': False, 'EnableDP': True, 'EnableEncryption': False, 'DPEpsilon': 0.5, 'DPDelta': 1e-05, 'DPSensitivity': 0.01, 'roundPrecision': 1, 'StdDevNoising': 0.1, 'epochsForAttack': 60, 'epochsForClassifier': 60, 'meanLambda': 1.2, 'enableAttackerFeatures': True, 'enableMean': False, 'unknownVarLambda': 0.25, 'perturbation_level': -4.0, 'outputDim': 11, 'modelType': 'NN'}
#
#
#
# <<<<<<<-------------------------------NumOfFeaturesToRecover: 12------------------------------->>>>>>>
# Running on device: cuda:0
# Writing log to file: /content/FLinferenceDefence/GRNA/log/drive-2023-08-17-17-59-04-attacker-36-victim-12-mean-False-type-NN-predict-0.2.csv
# n_attacker = 36, n_victim = 12
#
#
# <----------------- Running count: 1 / 2 ----------------->
# ...

# %% [markdown]
# # GRNA DP

# %%
# !python main-grna.py --outputDim 5 --modelType NN --DataFile news_cleaned.csv --LogFile news.csv --n_attacker 15 --n_victim 44 --runtimes 2 --EnablePREDVEL False --perturbation_level -4 --EnableDP True --DPEpsilon 0.1 --DPDelta 1e-5 --DPSensitivity 0.01
# Out:
# {'DataFile': 'news_cleaned.csv', 'LogFile': 'news.csv', 'n_attacker': 15, 'n_victim': 44, 'runtimes': 2, 'trainpart': 0.6, 'testpart': 0.2, 'predictpart': 0.2, 'enableConfRound': False, 'EnablePREDVEL': True, 'EnableNoising': False, 'EnableDropout': False, 'EnableDP': True, 'EnableEncryption': False, 'DPEpsilon': 0.1, 'DPDelta': 1e-05, 'DPSensitivity': 0.01, 'roundPrecision': 1, 'StdDevNoising': 0.1, 'epochsForAttack': 60, 'epochsForClassifier': 60, 'meanLambda': 1.2, 'enableAttackerFeatures': True, 'enableMean': False, 'unknownVarLambda': 0.25, 'perturbation_level': -4.0, 'outputDim': 5, 'modelType': 'NN'}
#
#
#
# <<<<<<<-------------------------------NumOfFeaturesToRecover: 44------------------------------->>>>>>>
# Running on device: cuda:0
# Writing log to file: /content/FLinferenceDefence/GRNA/log/news-2023-08-17-18-07-16-attacker-15-victim-44-mean-False-type-NN-predict-0.2.csv
# n_attacker = 15, n_victim = 44
#
#
# <----------------- Running count: 1 / 2 ----------------->
#
#
# ...

# %%
# !python main-grna.py --outputDim 5 --modelType NN --DataFile news_cleaned.csv --LogFile news.csv --n_attacker 30 --n_victim 29 --runtimes 2 --EnablePREDVEL False --perturbation_level -4 --EnableDP True --DPEpsilon 0.1 --DPDelta 1e-5 --DPSensitivity 0.01
# Out:
# {'DataFile': 'news_cleaned.csv', 'LogFile': 'news.csv', 'n_attacker': 30, 'n_victim': 29, 'runtimes': 2, 'trainpart': 0.6, 'testpart': 0.2, 'predictpart': 0.2, 'enableConfRound': False, 'EnablePREDVEL': True, 'EnableNoising': False, 'EnableDropout': False, 'EnableDP': True, 'EnableEncryption': False, 'DPEpsilon': 0.1, 'DPDelta': 1e-05, 'DPSensitivity': 0.01, 'roundPrecision': 1, 'StdDevNoising': 0.1, 'epochsForAttack': 60, 'epochsForClassifier': 60, 'meanLambda': 1.2, 'enableAttackerFeatures': True, 'enableMean': False, 'unknownVarLambda': 0.25, 'perturbation_level': -4.0, 'outputDim': 5, 'modelType': 'NN'}
#
#
#
# <<<<<<<-------------------------------NumOfFeaturesToRecover: 29------------------------------->>>>>>>
# Running on device: cuda:0
# Writing log to file: /content/FLinferenceDefence/GRNA/log/news-2023-08-17-18-12-35-attacker-30-victim-29-mean-False-type-NN-predict-0.2.csv
# n_attacker = 30, n_victim = 29
#
#
# <----------------- Running count: 1 / 2 ----------------->
#
#
# ...

# %%
# !python main-grna.py --outputDim 5 --modelType NN --DataFile news_cleaned.csv --LogFile news.csv --n_attacker 45 --n_victim 14 --runtimes 2 --EnablePREDVEL False --perturbation_level -4 --EnableDP True --DPEpsilon 0.1 --DPDelta 1e-5 --DPSensitivity 0.01
# Out:
# {'DataFile': 'news_cleaned.csv', 'LogFile': 'news.csv', 'n_attacker': 45, 'n_victim': 14, 'runtimes': 2, 'trainpart': 0.6, 'testpart': 0.2, 'predictpart': 0.2, 'enableConfRound': False, 'EnablePREDVEL': True, 'EnableNoising': False, 'EnableDropout': False, 'EnableDP': True, 'EnableEncryption': False, 'DPEpsilon': 0.1, 'DPDelta': 1e-05, 'DPSensitivity': 0.01, 'roundPrecision': 1, 'StdDevNoising': 0.1, 'epochsForAttack': 60, 'epochsForClassifier': 60, 'meanLambda': 1.2, 'enableAttackerFeatures': True, 'enableMean': False, 'unknownVarLambda': 0.25, 'perturbation_level': -4.0, 'outputDim': 5, 'modelType': 'NN'}
#
#
#
# <<<<<<<-------------------------------NumOfFeaturesToRecover: 14------------------------------->>>>>>>
# Running on device: cuda:0
# Writing log to file: /content/FLinferenceDefence/GRNA/log/news-2023-08-17-18-17-28-attacker-45-victim-14-mean-False-type-NN-predict-0.2.csv
# n_attacker = 45, n_victim = 14
#
#
# <----------------- Running count: 1 / 2 ----------------->
#
#
# ...

# %%
# !python main-grna.py --outputDim 5 --modelType RF --DataFile news_cleaned.csv --LogFile news.csv --n_attacker 15 --n_victim 44 --runtimes 2 --EnablePREDVEL False --perturbation_level -4 --EnableDP True --DPEpsilon 0.1 --DPDelta 1e-5 --DPSensitivity 0.01
# Out:
# {'DataFile': 'news_cleaned.csv', 'LogFile': 'news.csv', 'n_attacker': 15, 'n_victim': 44, 'runtimes': 2, 'trainpart': 0.6, 'testpart': 0.2, 'predictpart': 0.2, 'enableConfRound': False, 'EnablePREDVEL': True, 'EnableNoising': False, 'EnableDropout': False, 'EnableDP': True, 'EnableEncryption': False, 'DPEpsilon': 0.1, 'DPDelta': 1e-05, 'DPSensitivity': 0.01, 'roundPrecision': 1, 'StdDevNoising': 0.1, 'epochsForAttack': 60, 'epochsForClassifier': 60, 'meanLambda': 1.2, 'enableAttackerFeatures': True, 'enableMean': False, 'unknownVarLambda': 0.25, 'perturbation_level': -4.0, 'outputDim': 5, 'modelType': 'RF'}
#
#
#
# <<<<<<<-------------------------------NumOfFeaturesToRecover: 44------------------------------->>>>>>>
# Running on device: cuda:0
# Writing log to file: /content/FLinferenceDefence/GRNA/log/news-2023-08-17-18-21-50-attacker-15-victim-44-mean-False-type-RF-predict-0.2.csv
# n_attacker = 15, n_victim = 44
#
#
# <----------------- Running count: 1 / 2 ----------------->
#
#
# ...

# %%
# !python main-grna.py --outputDim 5 --modelType RF --DataFile news_cleaned.csv --LogFile news.csv --n_attacker 30 --n_victim 29 --runtimes 2 --EnablePREDVEL False --perturbation_level -4 --EnableDP True --DPEpsilon 0.1 --DPDelta 1e-5 --DPSensitivity 0.01
# Out:
# {'DataFile': 'news_cleaned.csv', 'LogFile': 'news.csv', 'n_attacker': 30, 'n_victim': 29, 'runtimes': 2, 'trainpart': 0.6, 'testpart': 0.2, 'predictpart': 0.2, 'enableConfRound': False, 'EnablePREDVEL': True, 'EnableNoising': False, 'EnableDropout': False, 'EnableDP': True, 'EnableEncryption': False, 'DPEpsilon': 0.1, 'DPDelta': 1e-05, 'DPSensitivity': 0.01, 'roundPrecision': 1, 'StdDevNoising': 0.1, 'epochsForAttack': 60, 'epochsForClassifier': 60, 'meanLambda': 1.2, 'enableAttackerFeatures': True, 'enableMean': False, 'unknownVarLambda': 0.25, 'perturbation_level': -4.0, 'outputDim': 5, 'modelType': 'RF'}
#
#
#
# <<<<<<<-------------------------------NumOfFeaturesToRecover: 29------------------------------->>>>>>>
# Running on device: cuda:0
# Writing log to file: /content/FLinferenceDefence/GRNA/log/news-2023-08-17-18-27-37-attacker-30-victim-29-mean-False-type-RF-predict-0.2.csv
# n_attacker = 30, n_victim = 29
#
#
# <----------------- Running count: 1 / 2 ----------------->
#
#
# ...

# %%
# !python main-grna.py --outputDim 5 --modelType RF --DataFile news_cleaned.csv --LogFile news.csv --n_attacker 45 --n_victim 14 --runtimes 2 --EnablePREDVEL False --perturbation_level -4 --EnableDP True --DPEpsilon 0.1 --DPDelta 1e-5 --DPSensitivity 0.01
# Out:
# {'DataFile': 'news_cleaned.csv', 'LogFile': 'news.csv', 'n_attacker': 45, 'n_victim': 14, 'runtimes': 2, 'trainpart': 0.6, 'testpart': 0.2, 'predictpart': 0.2, 'enableConfRound': False, 'EnablePREDVEL': True, 'EnableNoising': False, 'EnableDropout': False, 'EnableDP': True, 'EnableEncryption': False, 'DPEpsilon': 0.1, 'DPDelta': 1e-05, 'DPSensitivity': 0.01, 'roundPrecision': 1, 'StdDevNoising': 0.1, 'epochsForAttack': 60, 'epochsForClassifier': 60, 'meanLambda': 1.2, 'enableAttackerFeatures': True, 'enableMean': False, 'unknownVarLambda': 0.25, 'perturbation_level': -4.0, 'outputDim': 5, 'modelType': 'RF'}
#
#
#
# <<<<<<<-------------------------------NumOfFeaturesToRecover: 14------------------------------->>>>>>>
# Running on device: cuda:0
# Writing log to file: /content/FLinferenceDefence/GRNA/log/news-2023-08-17-18-32-50-attacker-45-victim-14-mean-False-type-RF-predict-0.2.csv
# n_attacker = 45, n_victim = 14
#
#
# <----------------- Running count: 1 / 2 ----------------->
#
#
# ...

# %%
# !python main-grna.py --outputDim 11 --modelType RF --DataFile drive_cleaned.csv --LogFile drive.csv --n_attacker 12 --n_victim 36 --runtimes 2 --EnablePREDVEL False --perturbation_level -4 --EnableDP True --DPEpsilon 0.1 --DPDelta 1e-5 --DPSensitivity 0.01
# Out:
# {'DataFile': 'drive_cleaned.csv', 'LogFile': 'drive.csv', 'n_attacker': 12, 'n_victim': 36, 'runtimes': 2, 'trainpart': 0.6, 'testpart': 0.2, 'predictpart': 0.2, 'enableConfRound': False, 'EnablePREDVEL': True, 'EnableNoising': False, 'EnableDropout': False, 'EnableDP': True, 'EnableEncryption': False, 'DPEpsilon': 0.1, 'DPDelta': 1e-05, 'DPSensitivity': 0.01, 'roundPrecision': 1, 'StdDevNoising': 0.1, 'epochsForAttack': 60, 'epochsForClassifier': 60, 'meanLambda': 1.2, 'enableAttackerFeatures': True, 'enableMean': False, 'unknownVarLambda': 0.25, 'perturbation_level': -4.0, 'outputDim': 11, 'modelType': 'RF'}
#
#
#
# <<<<<<<-------------------------------NumOfFeaturesToRecover: 36------------------------------->>>>>>>
# Running on device: cuda:0
# Writing log to file: /content/FLinferenceDefence/GRNA/log/drive-2023-08-17-18-37-39-attacker-12-victim-36-mean-False-type-RF-predict-0.2.csv
# n_attacker = 12, n_victim = 36
#
#
# <----------------- Running count: 1 / 2 ----------------->
# ...

# %%
# !python main-grna.py --outputDim 11 --modelType RF --DataFile drive_cleaned.csv --LogFile drive.csv --n_attacker 24 --n_victim 24 --runtimes 2 --EnablePREDVEL False --perturbation_level -4 --EnableDP True --DPEpsilon 0.1 --DPDelta 1e-5 --DPSensitivity 0.01
# Out:
# {'DataFile': 'drive_cleaned.csv', 'LogFile': 'drive.csv', 'n_attacker': 24, 'n_victim': 24, 'runtimes': 2, 'trainpart': 0.6, 'testpart': 0.2, 'predictpart': 0.2, 'enableConfRound': False, 'EnablePREDVEL': True, 'EnableNoising': False, 'EnableDropout': False, 'EnableDP': True, 'EnableEncryption': False, 'DPEpsilon': 0.1, 'DPDelta': 1e-05, 'DPSensitivity': 0.01, 'roundPrecision': 1, 'StdDevNoising': 0.1, 'epochsForAttack': 60, 'epochsForClassifier': 60, 'meanLambda': 1.2, 'enableAttackerFeatures': True, 'enableMean': False, 'unknownVarLambda': 0.25, 'perturbation_level': -4.0, 'outputDim': 11, 'modelType': 'RF'}
#
#
#
# <<<<<<<-------------------------------NumOfFeaturesToRecover: 24------------------------------->>>>>>>
# Running on device: cuda:0
# Writing log to file: /content/FLinferenceDefence/GRNA/log/drive-2023-08-17-18-47-46-attacker-24-victim-24-mean-False-type-RF-predict-0.2.csv
# n_attacker = 24, n_victim = 24
#
#
# <----------------- Running count: 1 / 2 ----------------->
# ...

# %%
# !python main-grna.py --outputDim 11 --modelType RF --DataFile drive_cleaned.csv --LogFile drive.csv --n_attacker 36 --n_victim 12 --runtimes 2 --EnablePREDVEL False --perturbation_level -4 --EnableDP True --DPEpsilon 0.1 --DPDelta 1e-5 --DPSensitivity 0.01
# Out:
# {'DataFile': 'drive_cleaned.csv', 'LogFile': 'drive.csv', 'n_attacker': 36, 'n_victim': 12, 'runtimes': 2, 'trainpart': 0.6, 'testpart': 0.2, 'predictpart': 0.2, 'enableConfRound': False, 'EnablePREDVEL': True, 'EnableNoising': False, 'EnableDropout': False, 'EnableDP': True, 'EnableEncryption': False, 'DPEpsilon': 0.1, 'DPDelta': 1e-05, 'DPSensitivity': 0.01, 'roundPrecision': 1, 'StdDevNoising': 0.1, 'epochsForAttack': 60, 'epochsForClassifier': 60, 'meanLambda': 1.2, 'enableAttackerFeatures': True, 'enableMean': False, 'unknownVarLambda': 0.25, 'perturbation_level': -4.0, 'outputDim': 11, 'modelType': 'RF'}
#
#
#
# <<<<<<<-------------------------------NumOfFeaturesToRecover: 12------------------------------->>>>>>>
# Running on device: cuda:0
# Writing log to file: /content/FLinferenceDefence/GRNA/log/drive-2023-08-17-18-57-11-attacker-36-victim-12-mean-False-type-RF-predict-0.2.csv
# n_attacker = 36, n_victim = 12
#
#
# <----------------- Running count: 1 / 2 ----------------->
# ...

# %%
# !python main-grna.py --outputDim 11 --modelType NN --DataFile drive_cleaned.csv --LogFile drive.csv --n_attacker 12 --n_victim 36 --runtimes 2 --EnablePREDVEL False --perturbation_level -4 --EnableDP True --DPEpsilon 0.1 --DPDelta 1e-5 --DPSensitivity 0.01
# Out:
# {'DataFile': 'drive_cleaned.csv', 'LogFile': 'drive.csv', 'n_attacker': 12, 'n_victim': 36, 'runtimes': 2, 'trainpart': 0.6, 'testpart': 0.2, 'predictpart': 0.2, 'enableConfRound': False, 'EnablePREDVEL': True, 'EnableNoising': False, 'EnableDropout': False, 'EnableDP': True, 'EnableEncryption': False, 'DPEpsilon': 0.1, 'DPDelta': 1e-05, 'DPSensitivity': 0.01, 'roundPrecision': 1, 'StdDevNoising': 0.1, 'epochsForAttack': 60, 'epochsForClassifier': 60, 'meanLambda': 1.2, 'enableAttackerFeatures': True, 'enableMean': False, 'unknownVarLambda': 0.25, 'perturbation_level': -4.0, 'outputDim': 11, 'modelType': 'NN'}
#
#
#
# <<<<<<<-------------------------------NumOfFeaturesToRecover: 36------------------------------->>>>>>>
# Running on device: cpu
# Writing log to file: /content/FLinferenceDefence/GRNA/log/drive-2023-08-17-21-57-05-attacker-12-victim-36-mean-False-type-NN-predict-0.2.csv
# n_attacker = 12, n_victim = 36
#
#
# <----------------- Running count: 1 / 2 ----------------->
#
# ...

# %%
# !python main-grna.py --outputDim 11 --modelType NN --DataFile drive_cleaned.csv --LogFile drive.csv --n_attacker 24 --n_victim 24 --runtimes 2 --EnablePREDVEL False --perturbation_level -4 --EnableDP True --DPEpsilon 0.1 --DPDelta 1e-5 --DPSensitivity 0.01
# Out:
# {'DataFile': 'drive_cleaned.csv', 'LogFile': 'drive.csv', 'n_attacker': 24, 'n_victim': 24, 'runtimes': 2, 'trainpart': 0.6, 'testpart': 0.2, 'predictpart': 0.2, 'enableConfRound': False, 'EnablePREDVEL': True, 'EnableNoising': False, 'EnableDropout': False, 'EnableDP': True, 'EnableEncryption': False, 'DPEpsilon': 0.1, 'DPDelta': 1e-05, 'DPSensitivity': 0.01, 'roundPrecision': 1, 'StdDevNoising': 0.1, 'epochsForAttack': 60, 'epochsForClassifier': 60, 'meanLambda': 1.2, 'enableAttackerFeatures': True, 'enableMean': False, 'unknownVarLambda': 0.25, 'perturbation_level': -4.0, 'outputDim': 11, 'modelType': 'NN'}
#
#
#
# <<<<<<<-------------------------------NumOfFeaturesToRecover: 24------------------------------->>>>>>>
# Running on device: cpu
# Writing log to file: /content/FLinferenceDefence/GRNA/log/drive-2023-08-17-22-17-41-attacker-24-victim-24-mean-False-type-NN-predict-0.2.csv
# n_attacker = 24, n_victim = 24
#
#
# <----------------- Running count: 1 / 2 ----------------->
#
# ...

# %%
# !python main-grna.py --outputDim 11 --modelType NN --DataFile drive_cleaned.csv --LogFile drive.csv --n_attacker 36 --n_victim 12 --runtimes 2 --EnablePREDVEL False --perturbation_level -4 --EnableDP True --DPEpsilon 0.1 --DPDelta 1e-5 --DPSensitivity 0.01
# Out:
# {'DataFile': 'drive_cleaned.csv', 'LogFile': 'drive.csv', 'n_attacker': 36, 'n_victim': 12, 'runtimes': 2, 'trainpart': 0.6, 'testpart': 0.2, 'predictpart': 0.2, 'enableConfRound': False, 'EnablePREDVEL': True, 'EnableNoising': False, 'EnableDropout': False, 'EnableDP': True, 'EnableEncryption': False, 'DPEpsilon': 0.1, 'DPDelta': 1e-05, 'DPSensitivity': 0.01, 'roundPrecision': 1, 'StdDevNoising': 0.1, 'epochsForAttack': 60, 'epochsForClassifier': 60, 'meanLambda': 1.2, 'enableAttackerFeatures': True, 'enableMean': False, 'unknownVarLambda': 0.25, 'perturbation_level': -4.0, 'outputDim': 11, 'modelType': 'NN'}
#
#
#
# <<<<<<<-------------------------------NumOfFeaturesToRecover: 12------------------------------->>>>>>>
# Running on device: cpu
# Writing log to file: /content/FLinferenceDefence/GRNA/log/drive-2023-08-17-22-38-13-attacker-36-victim-12-mean-False-type-NN-predict-0.2.csv
# n_attacker = 36, n_victim = 12
#
#
# <----------------- Running count: 1 / 2 ----------------->
#
# ...

# %% [markdown]
# # PETER GRNA DP 10

# %%
# !python main-grna.py --outputDim 5 --modelType NN --DataFile news_cleaned.csv --LogFile news.csv --n_attacker 15 --n_victim 44 --runtimes 2 --EnablePREDVEL True --perturbation_level -4 --EnableDP True --DPEpsilon 0.5 --DPDelta 1e-5 --DPSensitivity 0.01
# Out:
# {'DataFile': 'news_cleaned.csv', 'LogFile': 'news.csv', 'n_attacker': 15, 'n_victim': 44, 'runtimes': 2, 'trainpart': 0.6, 'testpart': 0.2, 'predictpart': 0.2, 'enableConfRound': False, 'EnablePREDVEL': True, 'EnableNoising': False, 'EnableDropout': False, 'EnableDP': True, 'EnableEncryption': False, 'DPEpsilon': 0.5, 'DPDelta': 1e-05, 'DPSensitivity': 0.01, 'roundPrecision': 1, 'StdDevNoising': 0.1, 'epochsForAttack': 60, 'epochsForClassifier': 60, 'meanLambda': 1.2, 'enableAttackerFeatures': True, 'enableMean': False, 'unknownVarLambda': 0.25, 'perturbation_level': -4.0, 'outputDim': 5, 'modelType': 'NN'}
#
#
#
# <<<<<<<-------------------------------NumOfFeaturesToRecover: 44------------------------------->>>>>>>
# Running on device: cpu
# Writing log to file: /content/FLinferenceDefence/GRNA/log/news-2023-08-17-22-58-04-attacker-15-victim-44-mean-False-type-NN-predict-0.2.csv
# n_attacker = 15, n_victim = 44
#
#
# <----------------- Running count: 1 / 2 ----------------->
#
#
# ...

# %%
# !python main-grna.py --outputDim 5 --modelType NN --DataFile news_cleaned.csv --LogFile news.csv --n_attacker 30 --n_victim 29 --runtimes 2 --EnablePREDVEL True --perturbation_level -4 --EnableDP True --DPEpsilon 0.5 --DPDelta 1e-5 --DPSensitivity 0.01
# Out:
# {'DataFile': 'news_cleaned.csv', 'LogFile': 'news.csv', 'n_attacker': 30, 'n_victim': 29, 'runtimes': 2, 'trainpart': 0.6, 'testpart': 0.2, 'predictpart': 0.2, 'enableConfRound': False, 'EnablePREDVEL': True, 'EnableNoising': False, 'EnableDropout': False, 'EnableDP': True, 'EnableEncryption': False, 'DPEpsilon': 0.5, 'DPDelta': 1e-05, 'DPSensitivity': 0.01, 'roundPrecision': 1, 'StdDevNoising': 0.1, 'epochsForAttack': 60, 'epochsForClassifier': 60, 'meanLambda': 1.2, 'enableAttackerFeatures': True, 'enableMean': False, 'unknownVarLambda': 0.25, 'perturbation_level': -4.0, 'outputDim': 5, 'modelType': 'NN'}
#
#
#
# <<<<<<<-------------------------------NumOfFeaturesToRecover: 29------------------------------->>>>>>>
# Running on device: cpu
# Writing log to file: /content/FLinferenceDefence/GRNA/log/news-2023-08-17-23-09-51-attacker-30-victim-29-mean-False-type-NN-predict-0.2.csv
# n_attacker = 30, n_victim = 29
#
#
# <----------------- Running count: 1 / 2 ----------------->
#
#
# ...

# %%
# !python main-grna.py --outputDim 5 --modelType NN --DataFile news_cleaned.csv --LogFile news.csv --n_attacker 45 --n_victim 14 --runtimes 2 --EnablePREDVEL True --perturbation_level -4 --EnableDP True --DPEpsilon 0.5 --DPDelta 1e-5 --DPSensitivity 0.01
# Out:
# {'DataFile': 'news_cleaned.csv', 'LogFile': 'news.csv', 'n_attacker': 45, 'n_victim': 14, 'runtimes': 2, 'trainpart': 0.6, 'testpart': 0.2, 'predictpart': 0.2, 'enableConfRound': False, 'EnablePREDVEL': True, 'EnableNoising': False, 'EnableDropout': False, 'EnableDP': True, 'EnableEncryption': False, 'DPEpsilon': 0.5, 'DPDelta': 1e-05, 'DPSensitivity': 0.01, 'roundPrecision': 1, 'StdDevNoising': 0.1, 'epochsForAttack': 60, 'epochsForClassifier': 60, 'meanLambda': 1.2, 'enableAttackerFeatures': True, 'enableMean': False, 'unknownVarLambda': 0.25, 'perturbation_level': -4.0, 'outputDim': 5, 'modelType': 'NN'}
#
#
#
# <<<<<<<-------------------------------NumOfFeaturesToRecover: 14------------------------------->>>>>>>
# Running on device: cpu
# Writing log to file: /content/FLinferenceDefence/GRNA/log/news-2023-08-17-23-20-20-attacker-45-victim-14-mean-False-type-NN-predict-0.2.csv
# n_attacker = 45, n_victim = 14
#
#
# <----------------- Running count: 1 / 2 ----------------->
#
#
# ...

# %%
# !python main-grna.py --outputDim 5 --modelType RF --DataFile news_cleaned.csv --LogFile news.csv --n_attacker 15 --n_victim 44 --runtimes 2 --EnablePREDVEL True --perturbation_level -4 --EnableDP True --DPEpsilon 0.5 --DPDelta 1e-5 --DPSensitivity 0.01
# Out:
# {'DataFile': 'news_cleaned.csv', 'LogFile': 'news.csv', 'n_attacker': 15, 'n_victim': 44, 'runtimes': 2, 'trainpart': 0.6, 'testpart': 0.2, 'predictpart': 0.2, 'enableConfRound': False, 'EnablePREDVEL': True, 'EnableNoising': False, 'EnableDropout': False, 'EnableDP': True, 'EnableEncryption': False, 'DPEpsilon': 0.5, 'DPDelta': 1e-05, 'DPSensitivity': 0.01, 'roundPrecision': 1, 'StdDevNoising': 0.1, 'epochsForAttack': 60, 'epochsForClassifier': 60, 'meanLambda': 1.2, 'enableAttackerFeatures': True, 'enableMean': False, 'unknownVarLambda': 0.25, 'perturbation_level': -4.0, 'outputDim': 5, 'modelType': 'RF'}
#
#
#
# <<<<<<<-------------------------------NumOfFeaturesToRecover: 44------------------------------->>>>>>>
# Running on device: cpu
# Writing log to file: /content/FLinferenceDefence/GRNA/log/news-2023-08-17-23-30-02-attacker-15-victim-44-mean-False-type-RF-predict-0.2.csv
# n_attacker = 15, n_victim = 44
#
#
# <----------------- Running count: 1 / 2 ----------------->
#
#
# ...

# %%
# !python main-grna.py --outputDim 5 --modelType RF --DataFile news_cleaned.csv --LogFile news.csv --n_attacker 30 --n_victim 29 --runtimes 2 --EnablePREDVEL True --perturbation_level -4 --EnableDP True --DPEpsilon 0.5 --DPDelta 1e-5 --DPSensitivity 0.01
# Out:
# {'DataFile': 'news_cleaned.csv', 'LogFile': 'news.csv', 'n_attacker': 30, 'n_victim': 29, 'runtimes': 2, 'trainpart': 0.6, 'testpart': 0.2, 'predictpart': 0.2, 'enableConfRound': False, 'EnablePREDVEL': True, 'EnableNoising': False, 'EnableDropout': False, 'EnableDP': True, 'EnableEncryption': False, 'DPEpsilon': 0.5, 'DPDelta': 1e-05, 'DPSensitivity': 0.01, 'roundPrecision': 1, 'StdDevNoising': 0.1, 'epochsForAttack': 60, 'epochsForClassifier': 60, 'meanLambda': 1.2, 'enableAttackerFeatures': True, 'enableMean': False, 'unknownVarLambda': 0.25, 'perturbation_level': -4.0, 'outputDim': 5, 'modelType': 'RF'}
#
#
#
# <<<<<<<-------------------------------NumOfFeaturesToRecover: 29------------------------------->>>>>>>
# Running on device: cpu
# Writing log to file: /content/FLinferenceDefence/GRNA/log/news-2023-08-17-23-49-43-attacker-30-victim-29-mean-False-type-RF-predict-0.2.csv
# n_attacker = 30, n_victim = 29
#
#
# <----------------- Running count: 1 / 2 ----------------->
#
#
# ...

# %%
# !python main-grna.py --outputDim 5 --modelType RF --DataFile news_cleaned.csv --LogFile news.csv --n_attacker 45 --n_victim 14 --runtimes 2 --EnablePREDVEL True --perturbation_level -4 --EnableDP True --DPEpsilon 0.5 --DPDelta 1e-5 --DPSensitivity 0.01
# Out:
# {'DataFile': 'news_cleaned.csv', 'LogFile': 'news.csv', 'n_attacker': 45, 'n_victim': 14, 'runtimes': 2, 'trainpart': 0.6, 'testpart': 0.2, 'predictpart': 0.2, 'enableConfRound': False, 'EnablePREDVEL': True, 'EnableNoising': False, 'EnableDropout': False, 'EnableDP': True, 'EnableEncryption': False, 'DPEpsilon': 0.5, 'DPDelta': 1e-05, 'DPSensitivity': 0.01, 'roundPrecision': 1, 'StdDevNoising': 0.1, 'epochsForAttack': 60, 'epochsForClassifier': 60, 'meanLambda': 1.2, 'enableAttackerFeatures': True, 'enableMean': False, 'unknownVarLambda': 0.25, 'perturbation_level': -4.0, 'outputDim': 5, 'modelType': 'RF'}
#
#
#
# <<<<<<<-------------------------------NumOfFeaturesToRecover: 14------------------------------->>>>>>>
# Running on device: cpu
# Writing log to file: /content/FLinferenceDefence/GRNA/log/news-2023-08-18-00-11-08-attacker-45-victim-14-mean-False-type-RF-predict-0.2.csv
# n_attacker = 45, n_victim = 14
#
#
# <----------------- Running count: 1 / 2 ----------------->
#
#
# ...

# %%
# !python main-grna.py --outputDim 11 --modelType RF --DataFile drive_cleaned.csv --LogFile drive.csv --n_attacker 12 --n_victim 36 --runtimes 2 --EnablePREDVEL True --perturbation_level -4 --EnableDP True --DPEpsilon 0.5 --DPDelta 1e-5 --DPSensitivity 0.01
# Out:
# {'DataFile': 'drive_cleaned.csv', 'LogFile': 'drive.csv', 'n_attacker': 12, 'n_victim': 36, 'runtimes': 2, 'trainpart': 0.6, 'testpart': 0.2, 'predictpart': 0.2, 'enableConfRound': False, 'EnablePREDVEL': True, 'EnableNoising': False, 'EnableDropout': False, 'EnableDP': True, 'EnableEncryption': False, 'DPEpsilon': 0.5, 'DPDelta': 1e-05, 'DPSensitivity': 0.01, 'roundPrecision': 1, 'StdDevNoising': 0.1, 'epochsForAttack': 60, 'epochsForClassifier': 60, 'meanLambda': 1.2, 'enableAttackerFeatures': True, 'enableMean': False, 'unknownVarLambda': 0.25, 'perturbation_level': -4.0, 'outputDim': 11, 'modelType': 'RF'}
#
#
#
# <<<<<<<-------------------------------NumOfFeaturesToRecover: 36------------------------------->>>>>>>
# Running on device: cpu
# Writing log to file: /content/FLinferenceDefence/GRNA/log/drive-2023-08-18-00-32-28-attacker-12-victim-36-mean-False-type-RF-predict-0.2.csv
# n_attacker = 12, n_victim = 36
#
#
# <----------------- Running count: 1 / 2 ----------------->
#
# ...

# %%
# !python main-grna.py --outputDim 11 --modelType RF --DataFile drive_cleaned.csv --LogFile drive.csv --n_attacker 24 --n_victim 24 --runtimes 2 --EnablePREDVEL True --perturbation_level -4 --EnableDP True --DPEpsilon 0.5 --DPDelta 1e-5 --DPSensitivity 0.01
# Out:
# {'DataFile': 'drive_cleaned.csv', 'LogFile': 'drive.csv', 'n_attacker': 24, 'n_victim': 24, 'runtimes': 2, 'trainpart': 0.6, 'testpart': 0.2, 'predictpart': 0.2, 'enableConfRound': False, 'EnablePREDVEL': True, 'EnableNoising': False, 'EnableDropout': False, 'EnableDP': True, 'EnableEncryption': False, 'DPEpsilon': 0.5, 'DPDelta': 1e-05, 'DPSensitivity': 0.01, 'roundPrecision': 1, 'StdDevNoising': 0.1, 'epochsForAttack': 60, 'epochsForClassifier': 60, 'meanLambda': 1.2, 'enableAttackerFeatures': True, 'enableMean': False, 'unknownVarLambda': 0.25, 'perturbation_level': -4.0, 'outputDim': 11, 'modelType': 'RF'}
#
#
#
# <<<<<<<-------------------------------NumOfFeaturesToRecover: 24------------------------------->>>>>>>
# Running on device: cpu
# Writing log to file: /content/FLinferenceDefence/GRNA/log/drive-2023-08-18-01-07-43-attacker-24-victim-24-mean-False-type-RF-predict-0.2.csv
# n_attacker = 24, n_victim = 24
#
#
# <----------------- Running count: 1 / 2 ----------------->
#
# ...

# %%
# !python main-grna.py --outputDim 11 --modelType RF --DataFile drive_cleaned.csv --LogFile drive.csv --n_attacker 36 --n_victim 12 --runtimes 2 --EnablePREDVEL True --perturbation_level -4 --EnableDP True --DPEpsilon 0.5 --DPDelta 1e-5 --DPSensitivity 0.01
# Out:
# {'DataFile': 'drive_cleaned.csv', 'LogFile': 'drive.csv', 'n_attacker': 36, 'n_victim': 12, 'runtimes': 2, 'trainpart': 0.6, 'testpart': 0.2, 'predictpart': 0.2, 'enableConfRound': False, 'EnablePREDVEL': True, 'EnableNoising': False, 'EnableDropout': False, 'EnableDP': True, 'EnableEncryption': False, 'DPEpsilon': 0.5, 'DPDelta': 1e-05, 'DPSensitivity': 0.01, 'roundPrecision': 1, 'StdDevNoising': 0.1, 'epochsForAttack': 60, 'epochsForClassifier': 60, 'meanLambda': 1.2, 'enableAttackerFeatures': True, 'enableMean': False, 'unknownVarLambda': 0.25, 'perturbation_level': -4.0, 'outputDim': 11, 'modelType': 'RF'}
#
#
#
# <<<<<<<-------------------------------NumOfFeaturesToRecover: 12------------------------------->>>>>>>
# Running on device: cpu
# Writing log to file: /content/FLinferenceDefence/GRNA/log/drive-2023-08-18-01-42-27-attacker-36-victim-12-mean-False-type-RF-predict-0.2.csv
# n_attacker = 36, n_victim = 12
#
#
# <----------------- Running count: 1 / 2 ----------------->
#
# ...

# %%
# !python main-grna.py --outputDim 11 --modelType NN --DataFile drive_cleaned.csv --LogFile drive.csv --n_attacker 12 --n_victim 36 --runtimes 2 --EnablePREDVEL True --perturbation_level -4 --EnableDP True --DPEpsilon 0.5 --DPDelta 1e-5 --DPSensitivity 0.01
# Out:
# {'DataFile': 'drive_cleaned.csv', 'LogFile': 'drive.csv', 'n_attacker': 12, 'n_victim': 36, 'runtimes': 2, 'trainpart': 0.6, 'testpart': 0.2, 'predictpart': 0.2, 'enableConfRound': False, 'EnablePREDVEL': True, 'EnableNoising': False, 'EnableDropout': False, 'EnableDP': True, 'EnableEncryption': False, 'DPEpsilon': 0.5, 'DPDelta': 1e-05, 'DPSensitivity': 0.01, 'roundPrecision': 1, 'StdDevNoising': 0.1, 'epochsForAttack': 60, 'epochsForClassifier': 60, 'meanLambda': 1.2, 'enableAttackerFeatures': True, 'enableMean': False, 'unknownVarLambda': 0.25, 'perturbation_level': -4.0, 'outputDim': 11, 'modelType': 'NN'}
#
#
#
# <<<<<<<-------------------------------NumOfFeaturesToRecover: 36------------------------------->>>>>>>
# Running on device: cpu
# Writing log to file: /content/FLinferenceDefence/GRNA/log/drive-2023-08-18-02-16-12-attacker-12-victim-36-mean-False-type-NN-predict-0.2.csv
# n_attacker = 12, n_victim = 36
#
#
# <----------------- Running count: 1 / 2 ----------------->
#
# ...

# %%
# !python main-grna.py --outputDim 11 --modelType NN --DataFile drive_cleaned.csv --LogFile drive.csv --n_attacker 24 --n_victim 24 --runtimes 2 --EnablePREDVEL True --perturbation_level -4 --EnableDP True --DPEpsilon 0.5 --DPDelta 1e-5 --DPSensitivity 0.01
# Out:
# {'DataFile': 'drive_cleaned.csv', 'LogFile': 'drive.csv', 'n_attacker': 24, 'n_victim': 24, 'runtimes': 2, 'trainpart': 0.6, 'testpart': 0.2, 'predictpart': 0.2, 'enableConfRound': False, 'EnablePREDVEL': True, 'EnableNoising': False, 'EnableDropout': False, 'EnableDP': True, 'EnableEncryption': False, 'DPEpsilon': 0.5, 'DPDelta': 1e-05, 'DPSensitivity': 0.01, 'roundPrecision': 1, 'StdDevNoising': 0.1, 'epochsForAttack': 60, 'epochsForClassifier': 60, 'meanLambda': 1.2, 'enableAttackerFeatures': True, 'enableMean': False, 'unknownVarLambda': 0.25, 'perturbation_level': -4.0, 'outputDim': 11, 'modelType': 'NN'}
#
#
#
# <<<<<<<-------------------------------NumOfFeaturesToRecover: 24------------------------------->>>>>>>
# Running on device: cpu
# Writing log to file: /content/FLinferenceDefence/GRNA/log/drive-2023-08-18-02-36-38-attacker-24-victim-24-mean-False-type-NN-predict-0.2.csv
# n_attacker = 24, n_victim = 24
#
#
# <----------------- Running count: 1 / 2 ----------------->
#
# ...

# %%
# !python main-grna.py --outputDim 11 --modelType NN --DataFile drive_cleaned.csv --LogFile drive.csv --n_attacker 36 --n_victim 12 --runtimes 2 --EnablePREDVEL True --perturbation_level -4 --EnableDP True --DPEpsilon 0.5 --DPDelta 1e-5 --DPSensitivity 0.01

# %% [markdown]
# # PETER GRNA DP 0.1

# %%
# !python main-grna.py --outputDim 5 --modelType NN --DataFile news_cleaned.csv --LogFile news.csv --n_attacker 15 --n_victim 44 --runtimes 2 --EnablePREDVEL True --perturbation_level -4 --EnableDP True --DPEpsilon 0.1 --DPDelta 1e-5 --DPSensitivity 0.01

# %%
# !python main-grna.py --outputDim 5 --modelType NN --DataFile news_cleaned.csv --LogFile news.csv --n_attacker 30 --n_victim 29 --runtimes 2 --EnablePREDVEL True --perturbation_level -4 --EnableDP True --DPEpsilon 0.1 --DPDelta 1e-5 --DPSensitivity 0.01

# %%
# !python main-grna.py --outputDim 5 --modelType NN --DataFile news_cleaned.csv --LogFile news.csv --n_attacker 45 --n_victim 14 --runtimes 2 --EnablePREDVEL True --perturbation_level -4 --EnableDP True --DPEpsilon 0.1 --DPDelta 1e-5 --DPSensitivity 0.01

# %%
# !python main-grna.py --outputDim 5 --modelType RF --DataFile news_cleaned.csv --LogFile news.csv --n_attacker 15 --n_victim 44 --runtimes 2 --EnablePREDVEL True --perturbation_level -4 --EnableDP True --DPEpsilon 0.1 --DPDelta 1e-5 --DPSensitivity 0.01

# %%
# !python main-grna.py --outputDim 5 --modelType RF --DataFile news_cleaned.csv --LogFile news.csv --n_attacker 30 --n_victim 29 --runtimes 2 --EnablePREDVEL True --perturbation_level -4 --EnableDP True --DPEpsilon 0.1 --DPDelta 1e-5 --DPSensitivity 0.01

# %%
# !python main-grna.py --outputDim 5 --modelType RF --DataFile news_cleaned.csv --LogFile news.csv --n_attacker 45 --n_victim 14 --runtimes 2 --EnablePREDVEL True --perturbation_level -4 --EnableDP True --DPEpsilon 0.1 --DPDelta 1e-5 --DPSensitivity 0.01

# %%
# !python main-grna.py --outputDim 11 --modelType RF --DataFile drive_cleaned.csv --LogFile drive.csv --n_attacker 12 --n_victim 36 --runtimes 2 --EnablePREDVEL True --perturbation_level -4 --EnableDP True --DPEpsilon 0.1 --DPDelta 1e-5 --DPSensitivity 0.01

# %%
# !python main-grna.py --outputDim 11 --modelType RF --DataFile drive_cleaned.csv --LogFile drive.csv --n_attacker 24 --n_victim 24 --runtimes 2 --EnablePREDVEL True --perturbation_level -4 --EnableDP True --DPEpsilon 0.1 --DPDelta 1e-5 --DPSensitivity 0.01

# %%
# !python main-grna.py --outputDim 11 --modelType RF --DataFile drive_cleaned.csv --LogFile drive.csv --n_attacker 36 --n_victim 12 --runtimes 2 --EnablePREDVEL True --perturbation_level -4 --EnableDP True --DPEpsilon 0.1 --DPDelta 1e-5 --DPSensitivity 0.01

# %%
# !python main-grna.py --outputDim 11 --modelType NN --DataFile drive_cleaned.csv --LogFile drive.csv --n_attacker 12 --n_victim 36 --runtimes 2 --EnablePREDVEL True --perturbation_level -4 --EnableDP True --DPEpsilon 0.1 --DPDelta 1e-5 --DPSensitivity 0.01

# %%
# !python main-grna.py --outputDim 11 --modelType NN --DataFile drive_cleaned.csv --LogFile drive.csv --n_attacker 24 --n_victim 24 --runtimes 2 --EnablePREDVEL True --perturbation_level -4 --EnableDP True --DPEpsilon 0.1 --DPDelta 1e-5 --DPSensitivity 0.01

# %%
# !python main-grna.py --outputDim 11 --modelType NN --DataFile drive_cleaned.csv --LogFile drive.csv --n_attacker 36 --n_victim 12 --runtimes 2 --EnablePREDVEL True --perturbation_level -4 --EnableDP True --DPEpsilon 0.1 --DPDelta 1e-5 --DPSensitivity 0.01

# %% [markdown]
# # End PREDVEL
