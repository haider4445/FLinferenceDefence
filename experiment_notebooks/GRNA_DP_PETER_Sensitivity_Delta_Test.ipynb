# %%
# !git clone https://github.com/haider4445/FLinferenceDefence.git
# Out:
# Cloning into 'FLinferenceDefence'...
# remote: Enumerating objects: 576, done.
# remote: Counting objects: 100% (512/512), done.
# remote: Compressing objects: 100% (228/228), done.
# remote: Total 576 (delta 373), reused 417 (delta 283), pack-reused 64
# Receiving objects: 100% (576/576), 65.27 MiB | 14.39 MiB/s, done.
# Resolving deltas: 100% (392/392), done.
# Updating files: 100% (344/344), done.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install diffprivlib
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 176.0/176.0 kB 3.9 MB/s eta 0:00:00
# ...

# %%
# !pip install tenseal
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 11.9 MB/s eta 0:00:00
# ...

# %%
# %cd FLinferenceDefence/GRNA
# Out:
# /content/FLinferenceDefence/GRNA

# %% [markdown]
# # GRNA DP Delta = 10^-3

# %%
# !python main-grna.py --outputDim 5 --modelType NN --DataFile news_cleaned.csv --LogFile news.csv --n_attacker 15 --n_victim 44 --runtimes 2 --EnablePREDVEL False --perturbation_level -4 --EnableDP True --DPEpsilon 1 --DPDelta 1e-3 --DPSensitivity 0.01
# Out:
# {'DataFile': 'news_cleaned.csv', 'LogFile': 'news.csv', 'n_attacker': 15, 'n_victim': 44, 'runtimes': 2, 'trainpart': 0.6, 'testpart': 0.2, 'predictpart': 0.2, 'enableConfRound': False, 'EnablePREDVEL': True, 'EnableNoising': False, 'EnableDropout': False, 'EnableDP': True, 'EnableEncryption': False, 'DPEpsilon': 1.0, 'DPDelta': 0.001, 'DPSensitivity': 0.01, 'roundPrecision': 1, 'StdDevNoising': 0.1, 'epochsForAttack': 60, 'epochsForClassifier': 60, 'meanLambda': 1.2, 'enableAttackerFeatures': True, 'enableMean': False, 'unknownVarLambda': 0.25, 'perturbation_level': -4.0, 'outputDim': 5, 'modelType': 'NN', 'results_file_path': '/content/drive/My Drive/results_output_GRNA.csv'}
#
#
#
# <<<<<<<-------------------------------NumOfFeaturesToRecover: 44------------------------------->>>>>>>
# Running on device: cuda:0
# Writing log to file: /content/FLinferenceDefence/GRNA/log/news-2023-09-27-03-37-33-attacker-15-victim-44-mean-False-type-NN-predict-0.2.csv
# ...

# %%
# !python main-grna.py --outputDim 5 --modelType NN --DataFile news_cleaned.csv --LogFile news.csv --n_attacker 30 --n_victim 29 --runtimes 2 --EnablePREDVEL False --perturbation_level -4 --EnableDP True --DPEpsilon 1 --DPDelta 1e-3 --DPSensitivity 0.01
# Out:
# {'DataFile': 'news_cleaned.csv', 'LogFile': 'news.csv', 'n_attacker': 30, 'n_victim': 29, 'runtimes': 2, 'trainpart': 0.6, 'testpart': 0.2, 'predictpart': 0.2, 'enableConfRound': False, 'EnablePREDVEL': True, 'EnableNoising': False, 'EnableDropout': False, 'EnableDP': True, 'EnableEncryption': False, 'DPEpsilon': 1.0, 'DPDelta': 0.001, 'DPSensitivity': 0.01, 'roundPrecision': 1, 'StdDevNoising': 0.1, 'epochsForAttack': 60, 'epochsForClassifier': 60, 'meanLambda': 1.2, 'enableAttackerFeatures': True, 'enableMean': False, 'unknownVarLambda': 0.25, 'perturbation_level': -4.0, 'outputDim': 5, 'modelType': 'NN', 'results_file_path': '/content/drive/My Drive/results_output_GRNA.csv'}
#
#
#
# <<<<<<<-------------------------------NumOfFeaturesToRecover: 29------------------------------->>>>>>>
# Running on device: cuda:0
# Writing log to file: /content/FLinferenceDefence/GRNA/log/news-2023-09-27-03-43-24-attacker-30-victim-29-mean-False-type-NN-predict-0.2.csv
# ...

# %%
# !python main-grna.py --outputDim 5 --modelType NN --DataFile news_cleaned.csv --LogFile news.csv --n_attacker 45 --n_victim 14 --runtimes 2 --EnablePREDVEL False --perturbation_level -4 --EnableDP True --DPEpsilon 1 --DPDelta 1e-3 --DPSensitivity 0.01
# Out:
# {'DataFile': 'news_cleaned.csv', 'LogFile': 'news.csv', 'n_attacker': 45, 'n_victim': 14, 'runtimes': 2, 'trainpart': 0.6, 'testpart': 0.2, 'predictpart': 0.2, 'enableConfRound': False, 'EnablePREDVEL': True, 'EnableNoising': False, 'EnableDropout': False, 'EnableDP': True, 'EnableEncryption': False, 'DPEpsilon': 1.0, 'DPDelta': 0.001, 'DPSensitivity': 0.01, 'roundPrecision': 1, 'StdDevNoising': 0.1, 'epochsForAttack': 60, 'epochsForClassifier': 60, 'meanLambda': 1.2, 'enableAttackerFeatures': True, 'enableMean': False, 'unknownVarLambda': 0.25, 'perturbation_level': -4.0, 'outputDim': 5, 'modelType': 'NN', 'results_file_path': '/content/drive/My Drive/results_output_GRNA.csv'}
#
#
#
# <<<<<<<-------------------------------NumOfFeaturesToRecover: 14------------------------------->>>>>>>
# Running on device: cuda:0
# Writing log to file: /content/FLinferenceDefence/GRNA/log/news-2023-09-27-03-48-29-attacker-45-victim-14-mean-False-type-NN-predict-0.2.csv
# ...

# %%
# !python main-grna.py --outputDim 5 --modelType RF --DataFile news_cleaned.csv --LogFile news.csv --n_attacker 15 --n_victim 44 --runtimes 2 --EnablePREDVEL False --perturbation_level -4 --EnableDP True --DPEpsilon 1 --DPDelta 1e-3 --DPSensitivity 0.01
# Out:
# {'DataFile': 'news_cleaned.csv', 'LogFile': 'news.csv', 'n_attacker': 15, 'n_victim': 44, 'runtimes': 2, 'trainpart': 0.6, 'testpart': 0.2, 'predictpart': 0.2, 'enableConfRound': False, 'EnablePREDVEL': True, 'EnableNoising': False, 'EnableDropout': False, 'EnableDP': True, 'EnableEncryption': False, 'DPEpsilon': 1.0, 'DPDelta': 0.001, 'DPSensitivity': 0.01, 'roundPrecision': 1, 'StdDevNoising': 0.1, 'epochsForAttack': 60, 'epochsForClassifier': 60, 'meanLambda': 1.2, 'enableAttackerFeatures': True, 'enableMean': False, 'unknownVarLambda': 0.25, 'perturbation_level': -4.0, 'outputDim': 5, 'modelType': 'RF', 'results_file_path': '/content/drive/My Drive/results_output_GRNA.csv'}
#
#
#
# <<<<<<<-------------------------------NumOfFeaturesToRecover: 44------------------------------->>>>>>>
# Running on device: cuda:0
# Writing log to file: /content/FLinferenceDefence/GRNA/log/news-2023-09-27-03-52-57-attacker-15-victim-44-mean-False-type-RF-predict-0.2.csv
# ...

# %%
# !python main-grna.py --outputDim 5 --modelType RF --DataFile news_cleaned.csv --LogFile news.csv --n_attacker 30 --n_victim 29 --runtimes 2 --EnablePREDVEL False --perturbation_level -4 --EnableDP True --DPEpsilon 1 --DPDelta 1e-3 --DPSensitivity 0.01
# Out:
# {'DataFile': 'news_cleaned.csv', 'LogFile': 'news.csv', 'n_attacker': 30, 'n_victim': 29, 'runtimes': 2, 'trainpart': 0.6, 'testpart': 0.2, 'predictpart': 0.2, 'enableConfRound': False, 'EnablePREDVEL': True, 'EnableNoising': False, 'EnableDropout': False, 'EnableDP': True, 'EnableEncryption': False, 'DPEpsilon': 1.0, 'DPDelta': 0.001, 'DPSensitivity': 0.01, 'roundPrecision': 1, 'StdDevNoising': 0.1, 'epochsForAttack': 60, 'epochsForClassifier': 60, 'meanLambda': 1.2, 'enableAttackerFeatures': True, 'enableMean': False, 'unknownVarLambda': 0.25, 'perturbation_level': -4.0, 'outputDim': 5, 'modelType': 'RF', 'results_file_path': '/content/drive/My Drive/results_output_GRNA.csv'}
#
#
#
# <<<<<<<-------------------------------NumOfFeaturesToRecover: 29------------------------------->>>>>>>
# Running on device: cuda:0
# Writing log to file: /content/FLinferenceDefence/GRNA/log/news-2023-09-27-03-58-58-attacker-30-victim-29-mean-False-type-RF-predict-0.2.csv
# ...

# %%
# !python main-grna.py --outputDim 5 --modelType RF --DataFile news_cleaned.csv --LogFile news.csv --n_attacker 45 --n_victim 14 --runtimes 2 --EnablePREDVEL False --perturbation_level -4 --EnableDP True --DPEpsilon 1 --DPDelta 1e-3 --DPSensitivity 0.01
# Out:
# {'DataFile': 'news_cleaned.csv', 'LogFile': 'news.csv', 'n_attacker': 45, 'n_victim': 14, 'runtimes': 2, 'trainpart': 0.6, 'testpart': 0.2, 'predictpart': 0.2, 'enableConfRound': False, 'EnablePREDVEL': True, 'EnableNoising': False, 'EnableDropout': False, 'EnableDP': True, 'EnableEncryption': False, 'DPEpsilon': 1.0, 'DPDelta': 0.001, 'DPSensitivity': 0.01, 'roundPrecision': 1, 'StdDevNoising': 0.1, 'epochsForAttack': 60, 'epochsForClassifier': 60, 'meanLambda': 1.2, 'enableAttackerFeatures': True, 'enableMean': False, 'unknownVarLambda': 0.25, 'perturbation_level': -4.0, 'outputDim': 5, 'modelType': 'RF', 'results_file_path': '/content/drive/My Drive/results_output_GRNA.csv'}
#
#
#
# <<<<<<<-------------------------------NumOfFeaturesToRecover: 14------------------------------->>>>>>>
# Running on device: cuda:0
# Writing log to file: /content/FLinferenceDefence/GRNA/log/news-2023-09-27-04-04-58-attacker-45-victim-14-mean-False-type-RF-predict-0.2.csv
# ...

# %%
# !python main-grna.py --outputDim 11 --modelType RF --DataFile drive_cleaned.csv --LogFile drive.csv --n_attacker 12 --n_victim 36 --runtimes 2 --EnablePREDVEL False --perturbation_level -4 --EnableDP True --DPEpsilon 1 --DPDelta 1e-3 --DPSensitivity 0.01
# Out:
# {'DataFile': 'drive_cleaned.csv', 'LogFile': 'drive.csv', 'n_attacker': 12, 'n_victim': 36, 'runtimes': 2, 'trainpart': 0.6, 'testpart': 0.2, 'predictpart': 0.2, 'enableConfRound': False, 'EnablePREDVEL': True, 'EnableNoising': False, 'EnableDropout': False, 'EnableDP': True, 'EnableEncryption': False, 'DPEpsilon': 1.0, 'DPDelta': 0.001, 'DPSensitivity': 0.01, 'roundPrecision': 1, 'StdDevNoising': 0.1, 'epochsForAttack': 60, 'epochsForClassifier': 60, 'meanLambda': 1.2, 'enableAttackerFeatures': True, 'enableMean': False, 'unknownVarLambda': 0.25, 'perturbation_level': -4.0, 'outputDim': 11, 'modelType': 'RF', 'results_file_path': '/content/drive/My Drive/results_output_GRNA.csv'}
#
#
#
# <<<<<<<-------------------------------NumOfFeaturesToRecover: 36------------------------------->>>>>>>
# Running on device: cuda:0
# Writing log to file: /content/FLinferenceDefence/GRNA/log/drive-2023-09-27-04-09-57-attacker-12-victim-36-mean-False-type-RF-predict-0.2.csv
# ...

# %%
# !python main-grna.py --outputDim 11 --modelType RF --DataFile drive_cleaned.csv --LogFile drive.csv --n_attacker 24 --n_victim 24 --runtimes 2 --EnablePREDVEL False --perturbation_level -4 --EnableDP True --DPEpsilon 1 --DPDelta 1e-3 --DPSensitivity 0.01
# Out:
# {'DataFile': 'drive_cleaned.csv', 'LogFile': 'drive.csv', 'n_attacker': 24, 'n_victim': 24, 'runtimes': 2, 'trainpart': 0.6, 'testpart': 0.2, 'predictpart': 0.2, 'enableConfRound': False, 'EnablePREDVEL': True, 'EnableNoising': False, 'EnableDropout': False, 'EnableDP': True, 'EnableEncryption': False, 'DPEpsilon': 1.0, 'DPDelta': 0.001, 'DPSensitivity': 0.01, 'roundPrecision': 1, 'StdDevNoising': 0.1, 'epochsForAttack': 60, 'epochsForClassifier': 60, 'meanLambda': 1.2, 'enableAttackerFeatures': True, 'enableMean': False, 'unknownVarLambda': 0.25, 'perturbation_level': -4.0, 'outputDim': 11, 'modelType': 'RF', 'results_file_path': '/content/drive/My Drive/results_output_GRNA.csv'}
#
#
#
# <<<<<<<-------------------------------NumOfFeaturesToRecover: 24------------------------------->>>>>>>
# Running on device: cuda:0
# Writing log to file: /content/FLinferenceDefence/GRNA/log/drive-2023-09-27-04-20-28-attacker-24-victim-24-mean-False-type-RF-predict-0.2.csv
# ...

# %%
# !python main-grna.py --outputDim 11 --modelType RF --DataFile drive_cleaned.csv --LogFile drive.csv --n_attacker 36 --n_victim 12 --runtimes 2 --EnablePREDVEL False --perturbation_level -4 --EnableDP True --DPEpsilon 1 --DPDelta 1e-3 --DPSensitivity 0.01
# Out:
# {'DataFile': 'drive_cleaned.csv', 'LogFile': 'drive.csv', 'n_attacker': 36, 'n_victim': 12, 'runtimes': 2, 'trainpart': 0.6, 'testpart': 0.2, 'predictpart': 0.2, 'enableConfRound': False, 'EnablePREDVEL': True, 'EnableNoising': False, 'EnableDropout': False, 'EnableDP': True, 'EnableEncryption': False, 'DPEpsilon': 1.0, 'DPDelta': 0.001, 'DPSensitivity': 0.01, 'roundPrecision': 1, 'StdDevNoising': 0.1, 'epochsForAttack': 60, 'epochsForClassifier': 60, 'meanLambda': 1.2, 'enableAttackerFeatures': True, 'enableMean': False, 'unknownVarLambda': 0.25, 'perturbation_level': -4.0, 'outputDim': 11, 'modelType': 'RF', 'results_file_path': '/content/drive/My Drive/results_output_GRNA.csv'}
#
#
#
# <<<<<<<-------------------------------NumOfFeaturesToRecover: 12------------------------------->>>>>>>
# Running on device: cuda:0
# Writing log to file: /content/FLinferenceDefence/GRNA/log/drive-2023-09-27-04-30-31-attacker-36-victim-12-mean-False-type-RF-predict-0.2.csv
# ...

# %%
# !python main-grna.py --outputDim 11 --modelType NN --DataFile drive_cleaned.csv --LogFile drive.csv --n_attacker 12 --n_victim 36 --runtimes 2 --EnablePREDVEL False --perturbation_level -4 --EnableDP True --DPEpsilon 1 --DPDelta 1e-3 --DPSensitivity 0.01
# Out:
# {'DataFile': 'drive_cleaned.csv', 'LogFile': 'drive.csv', 'n_attacker': 12, 'n_victim': 36, 'runtimes': 2, 'trainpart': 0.6, 'testpart': 0.2, 'predictpart': 0.2, 'enableConfRound': False, 'EnablePREDVEL': True, 'EnableNoising': False, 'EnableDropout': False, 'EnableDP': True, 'EnableEncryption': False, 'DPEpsilon': 1.0, 'DPDelta': 0.001, 'DPSensitivity': 0.01, 'roundPrecision': 1, 'StdDevNoising': 0.1, 'epochsForAttack': 60, 'epochsForClassifier': 60, 'meanLambda': 1.2, 'enableAttackerFeatures': True, 'enableMean': False, 'unknownVarLambda': 0.25, 'perturbation_level': -4.0, 'outputDim': 11, 'modelType': 'NN', 'results_file_path': '/content/drive/My Drive/results_output_GRNA.csv'}
#
#
#
# <<<<<<<-------------------------------NumOfFeaturesToRecover: 36------------------------------->>>>>>>
# Running on device: cuda:0
# Writing log to file: /content/FLinferenceDefence/GRNA/log/drive-2023-09-27-04-39-56-attacker-12-victim-36-mean-False-type-NN-predict-0.2.csv
# ...

# %%
# !python main-grna.py --outputDim 11 --modelType NN --DataFile drive_cleaned.csv --LogFile drive.csv --n_attacker 24 --n_victim 24 --runtimes 2 --EnablePREDVEL False --perturbation_level -4 --EnableDP True --DPEpsilon 1 --DPDelta 1e-3 --DPSensitivity 0.01
# Out:
# {'DataFile': 'drive_cleaned.csv', 'LogFile': 'drive.csv', 'n_attacker': 24, 'n_victim': 24, 'runtimes': 2, 'trainpart': 0.6, 'testpart': 0.2, 'predictpart': 0.2, 'enableConfRound': False, 'EnablePREDVEL': True, 'EnableNoising': False, 'EnableDropout': False, 'EnableDP': True, 'EnableEncryption': False, 'DPEpsilon': 1.0, 'DPDelta': 0.001, 'DPSensitivity': 0.01, 'roundPrecision': 1, 'StdDevNoising': 0.1, 'epochsForAttack': 60, 'epochsForClassifier': 60, 'meanLambda': 1.2, 'enableAttackerFeatures': True, 'enableMean': False, 'unknownVarLambda': 0.25, 'perturbation_level': -4.0, 'outputDim': 11, 'modelType': 'NN', 'results_file_path': '/content/drive/My Drive/results_output_GRNA.csv'}
#
#
#
# <<<<<<<-------------------------------NumOfFeaturesToRecover: 24------------------------------->>>>>>>
# Running on device: cuda:0
# Writing log to file: /content/FLinferenceDefence/GRNA/log/drive-2023-09-27-04-49-45-attacker-24-victim-24-mean-False-type-NN-predict-0.2.csv
# ...

# %%
# !python main-grna.py --outputDim 11 --modelType NN --DataFile drive_cleaned.csv --LogFile drive.csv --n_attacker 36 --n_victim 12 --runtimes 2 --EnablePREDVEL False --perturbation_level -4 --EnableDP True --DPEpsilon 1 --DPDelta 1e-3 --DPSensitivity 0.01
# Out:
# {'DataFile': 'drive_cleaned.csv', 'LogFile': 'drive.csv', 'n_attacker': 36, 'n_victim': 12, 'runtimes': 2, 'trainpart': 0.6, 'testpart': 0.2, 'predictpart': 0.2, 'enableConfRound': False, 'EnablePREDVEL': True, 'EnableNoising': False, 'EnableDropout': False, 'EnableDP': True, 'EnableEncryption': False, 'DPEpsilon': 1.0, 'DPDelta': 0.001, 'DPSensitivity': 0.01, 'roundPrecision': 1, 'StdDevNoising': 0.1, 'epochsForAttack': 60, 'epochsForClassifier': 60, 'meanLambda': 1.2, 'enableAttackerFeatures': True, 'enableMean': False, 'unknownVarLambda': 0.25, 'perturbation_level': -4.0, 'outputDim': 11, 'modelType': 'NN', 'results_file_path': '/content/drive/My Drive/results_output_GRNA.csv'}
#
#
#
# <<<<<<<-------------------------------NumOfFeaturesToRecover: 12------------------------------->>>>>>>
# Running on device: cuda:0
# Writing log to file: /content/FLinferenceDefence/GRNA/log/drive-2023-09-27-04-59-00-attacker-36-victim-12-mean-False-type-NN-predict-0.2.csv
# ...

# %% [markdown]
# # GRNA DP Delta 10^-2

# %%
# !python main-grna.py --outputDim 5 --modelType NN --DataFile news_cleaned.csv --LogFile news.csv --n_attacker 15 --n_victim 44 --runtimes 2 --EnablePREDVEL False --perturbation_level -4 --EnableDP True --DPEpsilon 1 --DPDelta 1e-2 --DPSensitivity 0.01
# Out:
# {'DataFile': 'news_cleaned.csv', 'LogFile': 'news.csv', 'n_attacker': 15, 'n_victim': 44, 'runtimes': 2, 'trainpart': 0.6, 'testpart': 0.2, 'predictpart': 0.2, 'enableConfRound': False, 'EnablePREDVEL': True, 'EnableNoising': False, 'EnableDropout': False, 'EnableDP': True, 'EnableEncryption': False, 'DPEpsilon': 1.0, 'DPDelta': 0.01, 'DPSensitivity': 0.01, 'roundPrecision': 1, 'StdDevNoising': 0.1, 'epochsForAttack': 60, 'epochsForClassifier': 60, 'meanLambda': 1.2, 'enableAttackerFeatures': True, 'enableMean': False, 'unknownVarLambda': 0.25, 'perturbation_level': -4.0, 'outputDim': 5, 'modelType': 'NN', 'results_file_path': '/content/drive/My Drive/results_output_GRNA.csv'}
#
#
#
# <<<<<<<-------------------------------NumOfFeaturesToRecover: 44------------------------------->>>>>>>
# Running on device: cuda:0
# Writing log to file: /content/FLinferenceDefence/GRNA/log/news-2023-09-27-05-07-25-attacker-15-victim-44-mean-False-type-NN-predict-0.2.csv
# ...

# %%
# !python main-grna.py --outputDim 5 --modelType NN --DataFile news_cleaned.csv --LogFile news.csv --n_attacker 30 --n_victim 29 --runtimes 2 --EnablePREDVEL False --perturbation_level -4 --EnableDP True --DPEpsilon 1 --DPDelta 1e-2 --DPSensitivity 0.01
# Out:
# {'DataFile': 'news_cleaned.csv', 'LogFile': 'news.csv', 'n_attacker': 30, 'n_victim': 29, 'runtimes': 2, 'trainpart': 0.6, 'testpart': 0.2, 'predictpart': 0.2, 'enableConfRound': False, 'EnablePREDVEL': True, 'EnableNoising': False, 'EnableDropout': False, 'EnableDP': True, 'EnableEncryption': False, 'DPEpsilon': 1.0, 'DPDelta': 0.01, 'DPSensitivity': 0.01, 'roundPrecision': 1, 'StdDevNoising': 0.1, 'epochsForAttack': 60, 'epochsForClassifier': 60, 'meanLambda': 1.2, 'enableAttackerFeatures': True, 'enableMean': False, 'unknownVarLambda': 0.25, 'perturbation_level': -4.0, 'outputDim': 5, 'modelType': 'NN', 'results_file_path': '/content/drive/My Drive/results_output_GRNA.csv'}
#
#
#
# <<<<<<<-------------------------------NumOfFeaturesToRecover: 29------------------------------->>>>>>>
# Running on device: cuda:0
# Writing log to file: /content/FLinferenceDefence/GRNA/log/news-2023-09-27-05-13-00-attacker-30-victim-29-mean-False-type-NN-predict-0.2.csv
# ...

# %%
# !python main-grna.py --outputDim 5 --modelType NN --DataFile news_cleaned.csv --LogFile news.csv --n_attacker 45 --n_victim 14 --runtimes 2 --EnablePREDVEL False --perturbation_level -4 --EnableDP True --DPEpsilon 1 --DPDelta 1e-2 --DPSensitivity 0.01
# Out:
# {'DataFile': 'news_cleaned.csv', 'LogFile': 'news.csv', 'n_attacker': 45, 'n_victim': 14, 'runtimes': 2, 'trainpart': 0.6, 'testpart': 0.2, 'predictpart': 0.2, 'enableConfRound': False, 'EnablePREDVEL': True, 'EnableNoising': False, 'EnableDropout': False, 'EnableDP': True, 'EnableEncryption': False, 'DPEpsilon': 1.0, 'DPDelta': 0.01, 'DPSensitivity': 0.01, 'roundPrecision': 1, 'StdDevNoising': 0.1, 'epochsForAttack': 60, 'epochsForClassifier': 60, 'meanLambda': 1.2, 'enableAttackerFeatures': True, 'enableMean': False, 'unknownVarLambda': 0.25, 'perturbation_level': -4.0, 'outputDim': 5, 'modelType': 'NN', 'results_file_path': '/content/drive/My Drive/results_output_GRNA.csv'}
#
#
#
# <<<<<<<-------------------------------NumOfFeaturesToRecover: 14------------------------------->>>>>>>
# Running on device: cuda:0
# Writing log to file: /content/FLinferenceDefence/GRNA/log/news-2023-09-27-05-18-20-attacker-45-victim-14-mean-False-type-NN-predict-0.2.csv
# ...

# %%
# !python main-grna.py --outputDim 5 --modelType RF --DataFile news_cleaned.csv --LogFile news.csv --n_attacker 15 --n_victim 44 --runtimes 2 --EnablePREDVEL False --perturbation_level -4 --EnableDP True --DPEpsilon 1 --DPDelta 1e-2 --DPSensitivity 0.01
# Out:
# {'DataFile': 'news_cleaned.csv', 'LogFile': 'news.csv', 'n_attacker': 15, 'n_victim': 44, 'runtimes': 2, 'trainpart': 0.6, 'testpart': 0.2, 'predictpart': 0.2, 'enableConfRound': False, 'EnablePREDVEL': True, 'EnableNoising': False, 'EnableDropout': False, 'EnableDP': True, 'EnableEncryption': False, 'DPEpsilon': 1.0, 'DPDelta': 0.01, 'DPSensitivity': 0.01, 'roundPrecision': 1, 'StdDevNoising': 0.1, 'epochsForAttack': 60, 'epochsForClassifier': 60, 'meanLambda': 1.2, 'enableAttackerFeatures': True, 'enableMean': False, 'unknownVarLambda': 0.25, 'perturbation_level': -4.0, 'outputDim': 5, 'modelType': 'RF', 'results_file_path': '/content/drive/My Drive/results_output_GRNA.csv'}
#
#
#
# <<<<<<<-------------------------------NumOfFeaturesToRecover: 44------------------------------->>>>>>>
# Running on device: cuda:0
# Writing log to file: /content/FLinferenceDefence/GRNA/log/news-2023-09-27-05-23-07-attacker-15-victim-44-mean-False-type-RF-predict-0.2.csv
# ...

# %%
# !python main-grna.py --outputDim 5 --modelType RF --DataFile news_cleaned.csv --LogFile news.csv --n_attacker 30 --n_victim 29 --runtimes 2 --EnablePREDVEL False --perturbation_level -4 --EnableDP True --DPEpsilon 1 --DPDelta 1e-2 --DPSensitivity 0.01
# Out:
# {'DataFile': 'news_cleaned.csv', 'LogFile': 'news.csv', 'n_attacker': 30, 'n_victim': 29, 'runtimes': 2, 'trainpart': 0.6, 'testpart': 0.2, 'predictpart': 0.2, 'enableConfRound': False, 'EnablePREDVEL': True, 'EnableNoising': False, 'EnableDropout': False, 'EnableDP': True, 'EnableEncryption': False, 'DPEpsilon': 1.0, 'DPDelta': 0.01, 'DPSensitivity': 0.01, 'roundPrecision': 1, 'StdDevNoising': 0.1, 'epochsForAttack': 60, 'epochsForClassifier': 60, 'meanLambda': 1.2, 'enableAttackerFeatures': True, 'enableMean': False, 'unknownVarLambda': 0.25, 'perturbation_level': -4.0, 'outputDim': 5, 'modelType': 'RF', 'results_file_path': '/content/drive/My Drive/results_output_GRNA.csv'}
#
#
#
# <<<<<<<-------------------------------NumOfFeaturesToRecover: 29------------------------------->>>>>>>
# Running on device: cuda:0
# Writing log to file: /content/FLinferenceDefence/GRNA/log/news-2023-09-27-05-29-10-attacker-30-victim-29-mean-False-type-RF-predict-0.2.csv
# ...

# %%
# !python main-grna.py --outputDim 5 --modelType RF --DataFile news_cleaned.csv --LogFile news.csv --n_attacker 45 --n_victim 14 --runtimes 2 --EnablePREDVEL False --perturbation_level -4 --EnableDP True --DPEpsilon 1 --DPDelta 1e-2 --DPSensitivity 0.01
# Out:
# {'DataFile': 'news_cleaned.csv', 'LogFile': 'news.csv', 'n_attacker': 45, 'n_victim': 14, 'runtimes': 2, 'trainpart': 0.6, 'testpart': 0.2, 'predictpart': 0.2, 'enableConfRound': False, 'EnablePREDVEL': True, 'EnableNoising': False, 'EnableDropout': False, 'EnableDP': True, 'EnableEncryption': False, 'DPEpsilon': 1.0, 'DPDelta': 0.01, 'DPSensitivity': 0.01, 'roundPrecision': 1, 'StdDevNoising': 0.1, 'epochsForAttack': 60, 'epochsForClassifier': 60, 'meanLambda': 1.2, 'enableAttackerFeatures': True, 'enableMean': False, 'unknownVarLambda': 0.25, 'perturbation_level': -4.0, 'outputDim': 5, 'modelType': 'RF', 'results_file_path': '/content/drive/My Drive/results_output_GRNA.csv'}
#
#
#
# <<<<<<<-------------------------------NumOfFeaturesToRecover: 14------------------------------->>>>>>>
# Running on device: cuda:0
# Writing log to file: /content/FLinferenceDefence/GRNA/log/news-2023-09-27-05-34-38-attacker-45-victim-14-mean-False-type-RF-predict-0.2.csv
# ...

# %%
# !python main-grna.py --outputDim 11 --modelType RF --DataFile drive_cleaned.csv --LogFile drive.csv --n_attacker 12 --n_victim 36 --runtimes 2 --EnablePREDVEL False --perturbation_level -4 --EnableDP True --DPEpsilon 1 --DPDelta 1e-2 --DPSensitivity 0.01
# Out:
# {'DataFile': 'drive_cleaned.csv', 'LogFile': 'drive.csv', 'n_attacker': 12, 'n_victim': 36, 'runtimes': 2, 'trainpart': 0.6, 'testpart': 0.2, 'predictpart': 0.2, 'enableConfRound': False, 'EnablePREDVEL': True, 'EnableNoising': False, 'EnableDropout': False, 'EnableDP': True, 'EnableEncryption': False, 'DPEpsilon': 1.0, 'DPDelta': 0.01, 'DPSensitivity': 0.01, 'roundPrecision': 1, 'StdDevNoising': 0.1, 'epochsForAttack': 60, 'epochsForClassifier': 60, 'meanLambda': 1.2, 'enableAttackerFeatures': True, 'enableMean': False, 'unknownVarLambda': 0.25, 'perturbation_level': -4.0, 'outputDim': 11, 'modelType': 'RF', 'results_file_path': '/content/drive/My Drive/results_output_GRNA.csv'}
#
#
#
# <<<<<<<-------------------------------NumOfFeaturesToRecover: 36------------------------------->>>>>>>
# Running on device: cuda:0
# Writing log to file: /content/FLinferenceDefence/GRNA/log/drive-2023-09-27-05-39-41-attacker-12-victim-36-mean-False-type-RF-predict-0.2.csv
# ...

# %%
# !python main-grna.py --outputDim 11 --modelType RF --DataFile drive_cleaned.csv --LogFile drive.csv --n_attacker 24 --n_victim 24 --runtimes 2 --EnablePREDVEL False --perturbation_level -4 --EnableDP True --DPEpsilon 1 --DPDelta 1e-2 --DPSensitivity 0.01
# Out:
# {'DataFile': 'drive_cleaned.csv', 'LogFile': 'drive.csv', 'n_attacker': 24, 'n_victim': 24, 'runtimes': 2, 'trainpart': 0.6, 'testpart': 0.2, 'predictpart': 0.2, 'enableConfRound': False, 'EnablePREDVEL': True, 'EnableNoising': False, 'EnableDropout': False, 'EnableDP': True, 'EnableEncryption': False, 'DPEpsilon': 1.0, 'DPDelta': 0.01, 'DPSensitivity': 0.01, 'roundPrecision': 1, 'StdDevNoising': 0.1, 'epochsForAttack': 60, 'epochsForClassifier': 60, 'meanLambda': 1.2, 'enableAttackerFeatures': True, 'enableMean': False, 'unknownVarLambda': 0.25, 'perturbation_level': -4.0, 'outputDim': 11, 'modelType': 'RF', 'results_file_path': '/content/drive/My Drive/results_output_GRNA.csv'}
#
#
#
# <<<<<<<-------------------------------NumOfFeaturesToRecover: 24------------------------------->>>>>>>
# Running on device: cuda:0
# Writing log to file: /content/FLinferenceDefence/GRNA/log/drive-2023-09-27-05-50-23-attacker-24-victim-24-mean-False-type-RF-predict-0.2.csv
# ...

# %%
# !python main-grna.py --outputDim 11 --modelType RF --DataFile drive_cleaned.csv --LogFile drive.csv --n_attacker 36 --n_victim 12 --runtimes 2 --EnablePREDVEL False --perturbation_level -4 --EnableDP True --DPEpsilon 1 --DPDelta 1e-2 --DPSensitivity 0.01
# Out:
# {'DataFile': 'drive_cleaned.csv', 'LogFile': 'drive.csv', 'n_attacker': 36, 'n_victim': 12, 'runtimes': 2, 'trainpart': 0.6, 'testpart': 0.2, 'predictpart': 0.2, 'enableConfRound': False, 'EnablePREDVEL': True, 'EnableNoising': False, 'EnableDropout': False, 'EnableDP': True, 'EnableEncryption': False, 'DPEpsilon': 1.0, 'DPDelta': 0.01, 'DPSensitivity': 0.01, 'roundPrecision': 1, 'StdDevNoising': 0.1, 'epochsForAttack': 60, 'epochsForClassifier': 60, 'meanLambda': 1.2, 'enableAttackerFeatures': True, 'enableMean': False, 'unknownVarLambda': 0.25, 'perturbation_level': -4.0, 'outputDim': 11, 'modelType': 'RF', 'results_file_path': '/content/drive/My Drive/results_output_GRNA.csv'}
#
#
#
# <<<<<<<-------------------------------NumOfFeaturesToRecover: 12------------------------------->>>>>>>
# Running on device: cuda:0
# Writing log to file: /content/FLinferenceDefence/GRNA/log/drive-2023-09-27-06-00-22-attacker-36-victim-12-mean-False-type-RF-predict-0.2.csv
# ...

# %%
# !python main-grna.py --outputDim 11 --modelType NN --DataFile drive_cleaned.csv --LogFile drive.csv --n_attacker 12 --n_victim 36 --runtimes 2 --EnablePREDVEL False --perturbation_level -4 --EnableDP True --DPEpsilon 1 --DPDelta 1e-2 --DPSensitivity 0.01
# Out:
# {'DataFile': 'drive_cleaned.csv', 'LogFile': 'drive.csv', 'n_attacker': 12, 'n_victim': 36, 'runtimes': 2, 'trainpart': 0.6, 'testpart': 0.2, 'predictpart': 0.2, 'enableConfRound': False, 'EnablePREDVEL': True, 'EnableNoising': False, 'EnableDropout': False, 'EnableDP': True, 'EnableEncryption': False, 'DPEpsilon': 1.0, 'DPDelta': 0.01, 'DPSensitivity': 0.01, 'roundPrecision': 1, 'StdDevNoising': 0.1, 'epochsForAttack': 60, 'epochsForClassifier': 60, 'meanLambda': 1.2, 'enableAttackerFeatures': True, 'enableMean': False, 'unknownVarLambda': 0.25, 'perturbation_level': -4.0, 'outputDim': 11, 'modelType': 'NN', 'results_file_path': '/content/drive/My Drive/results_output_GRNA.csv'}
#
#
#
# <<<<<<<-------------------------------NumOfFeaturesToRecover: 36------------------------------->>>>>>>
# Running on device: cuda:0
# Writing log to file: /content/FLinferenceDefence/GRNA/log/drive-2023-09-27-06-09-52-attacker-12-victim-36-mean-False-type-NN-predict-0.2.csv
# ...

# %%
# !python main-grna.py --outputDim 11 --modelType NN --DataFile drive_cleaned.csv --LogFile drive.csv --n_attacker 24 --n_victim 24 --runtimes 2 --EnablePREDVEL False --perturbation_level -4 --EnableDP True --DPEpsilon 1 --DPDelta 1e-2 --DPSensitivity 0.01
# Out:
# {'DataFile': 'drive_cleaned.csv', 'LogFile': 'drive.csv', 'n_attacker': 24, 'n_victim': 24, 'runtimes': 2, 'trainpart': 0.6, 'testpart': 0.2, 'predictpart': 0.2, 'enableConfRound': False, 'EnablePREDVEL': True, 'EnableNoising': False, 'EnableDropout': False, 'EnableDP': True, 'EnableEncryption': False, 'DPEpsilon': 1.0, 'DPDelta': 0.01, 'DPSensitivity': 0.01, 'roundPrecision': 1, 'StdDevNoising': 0.1, 'epochsForAttack': 60, 'epochsForClassifier': 60, 'meanLambda': 1.2, 'enableAttackerFeatures': True, 'enableMean': False, 'unknownVarLambda': 0.25, 'perturbation_level': -4.0, 'outputDim': 11, 'modelType': 'NN', 'results_file_path': '/content/drive/My Drive/results_output_GRNA.csv'}
#
#
#
# <<<<<<<-------------------------------NumOfFeaturesToRecover: 24------------------------------->>>>>>>
# Running on device: cuda:0
# Writing log to file: /content/FLinferenceDefence/GRNA/log/drive-2023-09-27-06-19-57-attacker-24-victim-24-mean-False-type-NN-predict-0.2.csv
# ...

# %%
# !python main-grna.py --outputDim 11 --modelType NN --DataFile drive_cleaned.csv --LogFile drive.csv --n_attacker 36 --n_victim 12 --runtimes 2 --EnablePREDVEL False --perturbation_level -4 --EnableDP True --DPEpsilon 1 --DPDelta 1e-2 --DPSensitivity 0.01
# Out:
# {'DataFile': 'drive_cleaned.csv', 'LogFile': 'drive.csv', 'n_attacker': 36, 'n_victim': 12, 'runtimes': 2, 'trainpart': 0.6, 'testpart': 0.2, 'predictpart': 0.2, 'enableConfRound': False, 'EnablePREDVEL': True, 'EnableNoising': False, 'EnableDropout': False, 'EnableDP': True, 'EnableEncryption': False, 'DPEpsilon': 1.0, 'DPDelta': 0.01, 'DPSensitivity': 0.01, 'roundPrecision': 1, 'StdDevNoising': 0.1, 'epochsForAttack': 60, 'epochsForClassifier': 60, 'meanLambda': 1.2, 'enableAttackerFeatures': True, 'enableMean': False, 'unknownVarLambda': 0.25, 'perturbation_level': -4.0, 'outputDim': 11, 'modelType': 'NN', 'results_file_path': '/content/drive/My Drive/results_output_GRNA.csv'}
#
#
#
# <<<<<<<-------------------------------NumOfFeaturesToRecover: 12------------------------------->>>>>>>
# Running on device: cuda:0
# Writing log to file: /content/FLinferenceDefence/GRNA/log/drive-2023-09-27-06-30-17-attacker-36-victim-12-mean-False-type-NN-predict-0.2.csv
# ...

# %% [markdown]
# # PETER GRNA DP Sensitivity 0.005

# %%
# !python main-grna.py --outputDim 5 --modelType NN --DataFile news_cleaned.csv --LogFile news.csv --n_attacker 15 --n_victim 44 --runtimes 2 --EnablePREDVEL True --perturbation_level -4 --EnableDP True --DPEpsilon 1 --DPDelta 1e-5 --DPSensitivity 0.005
# Out:
# {'DataFile': 'news_cleaned.csv', 'LogFile': 'news.csv', 'n_attacker': 15, 'n_victim': 44, 'runtimes': 2, 'trainpart': 0.6, 'testpart': 0.2, 'predictpart': 0.2, 'enableConfRound': False, 'EnablePREDVEL': True, 'EnableNoising': False, 'EnableDropout': False, 'EnableDP': True, 'EnableEncryption': False, 'DPEpsilon': 1.0, 'DPDelta': 1e-05, 'DPSensitivity': 0.005, 'roundPrecision': 1, 'StdDevNoising': 0.1, 'epochsForAttack': 60, 'epochsForClassifier': 60, 'meanLambda': 1.2, 'enableAttackerFeatures': True, 'enableMean': False, 'unknownVarLambda': 0.25, 'perturbation_level': -4.0, 'outputDim': 5, 'modelType': 'NN', 'results_file_path': '/content/drive/My Drive/results_output_GRNA.csv'}
#
#
#
# <<<<<<<-------------------------------NumOfFeaturesToRecover: 44------------------------------->>>>>>>
# Running on device: cuda:0
# Writing log to file: /content/FLinferenceDefence/GRNA/log/news-2023-09-27-06-39-52-attacker-15-victim-44-mean-False-type-NN-predict-0.2.csv
# ...

# %%
# !python main-grna.py --outputDim 5 --modelType NN --DataFile news_cleaned.csv --LogFile news.csv --n_attacker 30 --n_victim 29 --runtimes 2 --EnablePREDVEL True --perturbation_level -4 --EnableDP True --DPEpsilon 1 --DPDelta 1e-5 --DPSensitivity 0.005
# Out:
# {'DataFile': 'news_cleaned.csv', 'LogFile': 'news.csv', 'n_attacker': 30, 'n_victim': 29, 'runtimes': 2, 'trainpart': 0.6, 'testpart': 0.2, 'predictpart': 0.2, 'enableConfRound': False, 'EnablePREDVEL': True, 'EnableNoising': False, 'EnableDropout': False, 'EnableDP': True, 'EnableEncryption': False, 'DPEpsilon': 1.0, 'DPDelta': 1e-05, 'DPSensitivity': 0.005, 'roundPrecision': 1, 'StdDevNoising': 0.1, 'epochsForAttack': 60, 'epochsForClassifier': 60, 'meanLambda': 1.2, 'enableAttackerFeatures': True, 'enableMean': False, 'unknownVarLambda': 0.25, 'perturbation_level': -4.0, 'outputDim': 5, 'modelType': 'NN', 'results_file_path': '/content/drive/My Drive/results_output_GRNA.csv'}
#
#
#
# <<<<<<<-------------------------------NumOfFeaturesToRecover: 29------------------------------->>>>>>>
# Running on device: cuda:0
# Writing log to file: /content/FLinferenceDefence/GRNA/log/news-2023-09-27-06-46-11-attacker-30-victim-29-mean-False-type-NN-predict-0.2.csv
# ...

# %%
# !python main-grna.py --outputDim 5 --modelType NN --DataFile news_cleaned.csv --LogFile news.csv --n_attacker 45 --n_victim 14 --runtimes 2 --EnablePREDVEL True --perturbation_level -4 --EnableDP True --DPEpsilon 1 --DPDelta 1e-5 --DPSensitivity 0.005
# Out:
# {'DataFile': 'news_cleaned.csv', 'LogFile': 'news.csv', 'n_attacker': 45, 'n_victim': 14, 'runtimes': 2, 'trainpart': 0.6, 'testpart': 0.2, 'predictpart': 0.2, 'enableConfRound': False, 'EnablePREDVEL': True, 'EnableNoising': False, 'EnableDropout': False, 'EnableDP': True, 'EnableEncryption': False, 'DPEpsilon': 1.0, 'DPDelta': 1e-05, 'DPSensitivity': 0.005, 'roundPrecision': 1, 'StdDevNoising': 0.1, 'epochsForAttack': 60, 'epochsForClassifier': 60, 'meanLambda': 1.2, 'enableAttackerFeatures': True, 'enableMean': False, 'unknownVarLambda': 0.25, 'perturbation_level': -4.0, 'outputDim': 5, 'modelType': 'NN', 'results_file_path': '/content/drive/My Drive/results_output_GRNA.csv'}
#
#
#
# <<<<<<<-------------------------------NumOfFeaturesToRecover: 14------------------------------->>>>>>>
# Running on device: cuda:0
# Writing log to file: /content/FLinferenceDefence/GRNA/log/news-2023-09-27-06-51-58-attacker-45-victim-14-mean-False-type-NN-predict-0.2.csv
# ...

# %%
# !python main-grna.py --outputDim 5 --modelType RF --DataFile news_cleaned.csv --LogFile news.csv --n_attacker 15 --n_victim 44 --runtimes 2 --EnablePREDVEL True --perturbation_level -4 --EnableDP True --DPEpsilon 1 --DPDelta 1e-5 --DPSensitivity 0.005
# Out:
# {'DataFile': 'news_cleaned.csv', 'LogFile': 'news.csv', 'n_attacker': 15, 'n_victim': 44, 'runtimes': 2, 'trainpart': 0.6, 'testpart': 0.2, 'predictpart': 0.2, 'enableConfRound': False, 'EnablePREDVEL': True, 'EnableNoising': False, 'EnableDropout': False, 'EnableDP': True, 'EnableEncryption': False, 'DPEpsilon': 1.0, 'DPDelta': 1e-05, 'DPSensitivity': 0.005, 'roundPrecision': 1, 'StdDevNoising': 0.1, 'epochsForAttack': 60, 'epochsForClassifier': 60, 'meanLambda': 1.2, 'enableAttackerFeatures': True, 'enableMean': False, 'unknownVarLambda': 0.25, 'perturbation_level': -4.0, 'outputDim': 5, 'modelType': 'RF', 'results_file_path': '/content/drive/My Drive/results_output_GRNA.csv'}
#
#
#
# <<<<<<<-------------------------------NumOfFeaturesToRecover: 44------------------------------->>>>>>>
# Running on device: cuda:0
# Writing log to file: /content/FLinferenceDefence/GRNA/log/news-2023-09-27-06-57-09-attacker-15-victim-44-mean-False-type-RF-predict-0.2.csv
# ...

# %%
# !python main-grna.py --outputDim 5 --modelType RF --DataFile news_cleaned.csv --LogFile news.csv --n_attacker 30 --n_victim 29 --runtimes 2 --EnablePREDVEL True --perturbation_level -4 --EnableDP True --DPEpsilon 1 --DPDelta 1e-5 --DPSensitivity 0.005

# %%
# !python main-grna.py --outputDim 5 --modelType RF --DataFile news_cleaned.csv --LogFile news.csv --n_attacker 45 --n_victim 14 --runtimes 2 --EnablePREDVEL True --perturbation_level -4 --EnableDP True --DPEpsilon 1 --DPDelta 1e-5 --DPSensitivity 0.005

# %%
# !python main-grna.py --outputDim 11 --modelType RF --DataFile drive_cleaned.csv --LogFile drive.csv --n_attacker 12 --n_victim 36 --runtimes 2 --EnablePREDVEL True --perturbation_level -4 --EnableDP True --DPEpsilon 1 --DPDelta 1e-5 --DPSensitivity 0.005

# %%
# !python main-grna.py --outputDim 11 --modelType RF --DataFile drive_cleaned.csv --LogFile drive.csv --n_attacker 24 --n_victim 24 --runtimes 2 --EnablePREDVEL True --perturbation_level -4 --EnableDP True --DPEpsilon 1 --DPDelta 1e-5 --DPSensitivity 0.005

# %%
# !python main-grna.py --outputDim 11 --modelType RF --DataFile drive_cleaned.csv --LogFile drive.csv --n_attacker 36 --n_victim 12 --runtimes 2 --EnablePREDVEL True --perturbation_level -4 --EnableDP True --DPEpsilon 1 --DPDelta 1e-5 --DPSensitivity 0.005

# %%
# !python main-grna.py --outputDim 11 --modelType NN --DataFile drive_cleaned.csv --LogFile drive.csv --n_attacker 12 --n_victim 36 --runtimes 2 --EnablePREDVEL True --perturbation_level -4 --EnableDP True --DPEpsilon 1 --DPDelta 1e-5 --DPSensitivity 0.005

# %%
# !python main-grna.py --outputDim 11 --modelType NN --DataFile drive_cleaned.csv --LogFile drive.csv --n_attacker 24 --n_victim 24 --runtimes 2 --EnablePREDVEL True --perturbation_level -4 --EnableDP True --DPEpsilon 1 --DPDelta 1e-5 --DPSensitivity 0.005

# %%
# !python main-grna.py --outputDim 11 --modelType NN --DataFile drive_cleaned.csv --LogFile drive.csv --n_attacker 36 --n_victim 12 --runtimes 2 --EnablePREDVEL True --perturbation_level -4 --EnableDP True --DPEpsilon 1 --DPDelta 1e-5 --DPSensitivity 0.005

# %% [markdown]
# # PETER GRNA DP Sensitivity 0.1

# %%
# !python main-grna.py --outputDim 5 --modelType NN --DataFile news_cleaned.csv --LogFile news.csv --n_attacker 15 --n_victim 44 --runtimes 2 --EnablePREDVEL True --perturbation_level -4 --EnableDP True --DPEpsilon 1 --DPDelta 1e-5 --DPSensitivity 0.1

# %%
# !python main-grna.py --outputDim 5 --modelType NN --DataFile news_cleaned.csv --LogFile news.csv --n_attacker 30 --n_victim 29 --runtimes 2 --EnablePREDVEL True --perturbation_level -4 --EnableDP True --DPEpsilon 1 --DPDelta 1e-5 --DPSensitivity 0.1

# %%
# !python main-grna.py --outputDim 5 --modelType NN --DataFile news_cleaned.csv --LogFile news.csv --n_attacker 45 --n_victim 14 --runtimes 2 --EnablePREDVEL True --perturbation_level -4 --EnableDP True --DPEpsilon 1 --DPDelta 1e-5 --DPSensitivity 0.1

# %%
# !python main-grna.py --outputDim 5 --modelType RF --DataFile news_cleaned.csv --LogFile news.csv --n_attacker 15 --n_victim 44 --runtimes 2 --EnablePREDVEL True --perturbation_level -4 --EnableDP True --DPEpsilon 1 --DPDelta 1e-5 --DPSensitivity 0.1

# %%
# !python main-grna.py --outputDim 5 --modelType RF --DataFile news_cleaned.csv --LogFile news.csv --n_attacker 30 --n_victim 29 --runtimes 2 --EnablePREDVEL True --perturbation_level -4 --EnableDP True --DPEpsilon 1 --DPDelta 1e-5 --DPSensitivity 0.1

# %%
# !python main-grna.py --outputDim 5 --modelType RF --DataFile news_cleaned.csv --LogFile news.csv --n_attacker 45 --n_victim 14 --runtimes 2 --EnablePREDVEL True --perturbation_level -4 --EnableDP True --DPEpsilon 1 --DPDelta 1e-5 --DPSensitivity 0.1

# %%
# !python main-grna.py --outputDim 11 --modelType RF --DataFile drive_cleaned.csv --LogFile drive.csv --n_attacker 12 --n_victim 36 --runtimes 2 --EnablePREDVEL True --perturbation_level -4 --EnableDP True --DPEpsilon 1 --DPDelta 1e-5 --DPSensitivity 0.1

# %%
# !python main-grna.py --outputDim 11 --modelType RF --DataFile drive_cleaned.csv --LogFile drive.csv --n_attacker 24 --n_victim 24 --runtimes 2 --EnablePREDVEL True --perturbation_level -4 --EnableDP True --DPEpsilon 1 --DPDelta 1e-5 --DPSensitivity 0.1

# %%
# !python main-grna.py --outputDim 11 --modelType RF --DataFile drive_cleaned.csv --LogFile drive.csv --n_attacker 36 --n_victim 12 --runtimes 2 --EnablePREDVEL True --perturbation_level -4 --EnableDP True --DPEpsilon 1 --DPDelta 1e-5 --DPSensitivity 0.1

# %%
# !python main-grna.py --outputDim 11 --modelType NN --DataFile drive_cleaned.csv --LogFile drive.csv --n_attacker 12 --n_victim 36 --runtimes 2 --EnablePREDVEL True --perturbation_level -4 --EnableDP True --DPEpsilon 1 --DPDelta 1e-5 --DPSensitivity 0.1

# %%
# !python main-grna.py --outputDim 11 --modelType NN --DataFile drive_cleaned.csv --LogFile drive.csv --n_attacker 24 --n_victim 24 --runtimes 2 --EnablePREDVEL True --perturbation_level -4 --EnableDP True --DPEpsilon 1 --DPDelta 1e-5 --DPSensitivity 0.1

# %%
# !python main-grna.py --outputDim 11 --modelType NN --DataFile drive_cleaned.csv --LogFile drive.csv --n_attacker 36 --n_victim 12 --runtimes 2 --EnablePREDVEL True --perturbation_level -4 --EnableDP True --DPEpsilon 1 --DPDelta 1e-5 --DPSensitivity 0.1

# %% [markdown]
# # End PREDVEL
